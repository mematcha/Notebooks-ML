# %% [markdown]
# # [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/harpreetsahota204/fiftyone_video_workshop/blob/main/workshop.ipynb)
#
# # Understanding Video Data at Scale
# ### A Hands-On Workshop with Action100M and FiftyOne
#
# ---
#
# Video is a hard modality to work with.
#
# You're dealing with more data, temporal complexity, and annotation workflows that don't scale. This notebook tackles a practical question: **given a large video dataset, how do you understand what's in it without manually watching thousands of clips?**
#
# We're working with a subset of **[Action100M preview](https://www.arxiv.org/abs/2601.10592)**. In this subset there are 1,144 YouTube videos, each clipped to 90 seconds, annotated with a hierarchical *Tree-of-Captions* structure produced by a fully automated AI pipeline: V-JEPA 2 for segmentation, PerceptionLM-3B and Llama-3.2-Vision-11B for captioning, and GPT-OSS-120B with multi-round Self-Refine for structured annotation extraction.
#
# Every label in this dataset was written by a model. None of it was seen by a human annotator.
#
# As AI-generated datasets become the norm, **the skill of interrogating machine-generated annotations is increasingly important**. This notebook shows you how to do that systematically.
#
# ---
#
# ### What We'll Build
#
# |  | Question | Tools |
# |---|---|---|
# | 1. What We Were Given | What does this dataset claim to contain? | FiftyOne App |
# | 2. Three Lenses | What does the raw data actually look like? | Qwen3-VL-Embedding, Molmo2, Sentence Transformers |
# | 3. The Second Opinion | Does a second model agree with the first? | Qwen3-VL |
# | 4. Measuring Agreement | How much do they agree, per sample? | Text Evaluation Plugin |
# | 5. Grounding the Hard Cases | Where they disagree, who's right? | Molmo2 |
# | 6. The Payoff | What can I now do with this? | FiftyOne App |
#
# By the end, you'll have a **confidence map** of the dataset's annotations and a reusable workflow for understanding any video dataset with AI-generated labels.

# %%
# !pip install fiftyone
# Out:
# Collecting fiftyone
#   Downloading fiftyone-1.14.0-py3-none-any.whl.metadata (22 kB)
# Collecting Deprecated (from fiftyone)
#   Downloading deprecated-1.3.1-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from fiftyone) (26.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from fiftyone) (75.2.0)
# Requirement already satisfied: aiofiles<26,>=20 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (24.1.0)
# Collecting argcomplete<4,>=2 (from fiftyone)
#   Downloading argcomplete-3.6.3-py3-none-any.whl.metadata (16 kB)
# Collecting async_lru<3,>=2 (from fiftyone)
#   Downloading async_lru-2.3.0-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: beautifulsoup4<5,>=2 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (4.13.5)
# Collecting boto3<2,>=1 (from fiftyone)
#   Downloading boto3-1.42.82-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: cachetools<7,>=5 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (6.2.6)
# Collecting dacite<2,>=1.6.0 (from fiftyone)
#   Downloading dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: dill<0.5,>=0.1 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (0.3.8)
# Collecting exceptiongroup<2,>=1 (from fiftyone)
#   Downloading exceptiongroup-1.3.1-py3-none-any.whl.metadata (6.7 kB)
# Collecting ftfy<7,>=4 (from fiftyone)
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: humanize<5,>=2 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (4.15.0)
# Collecting hypercorn<0.19,>=0.13.2 (from fiftyone)
#   Downloading hypercorn-0.18.0-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: Jinja2<4,>=3 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (3.1.6)
# Requirement already satisfied: jsonpatch<2,>=1 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (1.33)
# Collecting mongoengine~=0.29.1 (from fiftyone)
#   Downloading mongoengine-0.29.3-py3-none-any.whl.metadata (7.0 kB)
# Collecting motor~=3.6.0 (from fiftyone)
#   Downloading motor-3.6.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: Pillow!=11.2.*,>=6.2 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (11.3.0)
# Collecting plotly<7,>=6.1.1 (from fiftyone)
#   Downloading plotly-6.6.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting pprintpp<0.5,>=0.1 (from fiftyone)
#   Downloading pprintpp-0.4.0-py2.py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: psutil<8,>=5 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (5.9.5)
# Collecting pydash<9,>=6 (from fiftyone)
#   Downloading pydash-8.0.6-py3-none-any.whl.metadata (3.4 kB)
# Collecting pymongo~=4.9.2 (from fiftyone)
#   Downloading pymongo-4.9.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: pytz in /usr/local/lib/python3.12/dist-packages (from fiftyone) (2025.2)
# Requirement already satisfied: PyYAML<7,>=4 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (6.0.3)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from fiftyone) (2025.11.3)
# Collecting retrying<2,>=1 (from fiftyone)
#   Downloading retrying-1.4.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting sseclient-py<2,>=1.7.2 (from fiftyone)
#   Downloading sseclient_py-1.9.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: sse-starlette<4,>=0.10.3 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (3.3.4)
# Requirement already satisfied: starlette<0.53,>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (0.52.1)
# Collecting strawberry-graphql<0.292.0,>=0.262.4 (from fiftyone)
#   Downloading strawberry_graphql-0.291.3-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: tabulate<0.10,>=0.7 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (0.9.0)
# Requirement already satisfied: tqdm<5,>=2 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (4.67.3)
# Collecting xmltodict<2,>=1 (from fiftyone)
#   Downloading xmltodict-1.0.4-py3-none-any.whl.metadata (14 kB)
# Collecting universal-analytics-python3<2,>=1.0.1 (from fiftyone)
#   Downloading universal_analytics_python3-1.1.1-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: matplotlib<4 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (3.10.0)
# Requirement already satisfied: numpy<3 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (2.0.2)
# Requirement already satisfied: opencv-python-headless<5 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (4.13.0.92)
# Requirement already satisfied: pandas<4 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (2.2.2)
# Requirement already satisfied: rtree<2 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (1.4.1)
# Requirement already satisfied: scikit-learn<2 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (1.6.1)
# Requirement already satisfied: scikit-image<1 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (0.25.2)
# Requirement already satisfied: scipy<2 in /usr/local/lib/python3.12/dist-packages (from fiftyone) (1.16.3)
# Collecting fiftyone-brain<0.22,>=0.21.5 (from fiftyone)
#   Downloading fiftyone_brain-0.21.5-py3-none-any.whl.metadata (4.8 kB)
# Collecting fiftyone-db<2.0,>=0.4 (from fiftyone)
#   Downloading fiftyone_db-1.4.1.tar.gz (8.6 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting voxel51-eta<0.16,>=0.15.3 (from fiftyone)
#   Downloading voxel51_eta-0.15.4-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4<5,>=2->fiftyone) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4<5,>=2->fiftyone) (4.15.0)
# Collecting botocore<1.43.0,>=1.42.82 (from boto3<2,>=1->fiftyone)
#   Downloading botocore-1.42.82-py3-none-any.whl.metadata (5.9 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3<2,>=1->fiftyone)
#   Downloading jmespath-1.1.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.17.0,>=0.16.0 (from boto3<2,>=1->fiftyone)
#   Downloading s3transfer-0.16.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from ftfy<7,>=4->fiftyone) (0.6.0)
# Requirement already satisfied: h11 in /usr/local/lib/python3.12/dist-packages (from hypercorn<0.19,>=0.13.2->fiftyone) (0.16.0)
# Requirement already satisfied: h2>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from hypercorn<0.19,>=0.13.2->fiftyone) (4.3.0)
# Collecting priority (from hypercorn<0.19,>=0.13.2->fiftyone)
#   Downloading priority-2.0.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting wsproto>=0.14.0 (from hypercorn<0.19,>=0.13.2->fiftyone)
#   Downloading wsproto-1.3.2-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from Jinja2<4,>=3->fiftyone) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2,>=1->fiftyone) (3.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->fiftyone) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->fiftyone) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->fiftyone) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->fiftyone) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->fiftyone) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->fiftyone) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<4->fiftyone) (2025.3)
# Requirement already satisfied: narwhals>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from plotly<7,>=6.1.1->fiftyone) (2.18.1)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo~=4.9.2->fiftyone)
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image<1->fiftyone) (3.6.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image<1->fiftyone) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image<1->fiftyone) (2026.3.3)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image<1->fiftyone) (0.5)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<2->fiftyone) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<2->fiftyone) (3.6.0)
# Requirement already satisfied: anyio>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from sse-starlette<4,>=0.10.3->fiftyone) (4.13.0)
# Collecting cross-web>=0.4.0 (from strawberry-graphql<0.292.0,>=0.262.4->fiftyone)
#   Downloading cross_web-0.4.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting graphql-core<3.4.0,>=3.2.0 (from strawberry-graphql<0.292.0,>=0.262.4->fiftyone)
#   Downloading graphql_core-3.2.8-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: httpx>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from universal-analytics-python3<2,>=1.0.1->fiftyone) (0.28.1)
# Requirement already satisfied: glob2 in /usr/local/lib/python3.12/dist-packages (from voxel51-eta<0.16,>=0.15.3->fiftyone) (0.7)
# Collecting jsonlines (from voxel51-eta<0.16,>=0.15.3->fiftyone)
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting paramiko<4,>=3 (from voxel51-eta<0.16,>=0.15.3->fiftyone)
#   Downloading paramiko-3.5.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting py7zr (from voxel51-eta<0.16,>=0.15.3->fiftyone)
#   Downloading py7zr-1.1.0-py3-none-any.whl.metadata (17 kB)
# Collecting rarfile (from voxel51-eta<0.16,>=0.15.3->fiftyone)
#   Downloading rarfile-4.2-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from voxel51-eta<0.16,>=0.15.3->fiftyone) (2.32.4)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.12/dist-packages (from voxel51-eta<0.16,>=0.15.3->fiftyone) (2.4.0)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.12/dist-packages (from voxel51-eta<0.16,>=0.15.3->fiftyone) (5.3.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.12/dist-packages (from voxel51-eta<0.16,>=0.15.3->fiftyone) (2.5.0)
# Requirement already satisfied: wrapt<3,>=1.10 in /usr/local/lib/python3.12/dist-packages (from Deprecated->fiftyone) (2.1.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio>=4.7.0->sse-starlette<4,>=0.10.3->fiftyone) (3.11)
# Requirement already satisfied: hyperframe<7,>=6.1 in /usr/local/lib/python3.12/dist-packages (from h2>=4.3.0->hypercorn<0.19,>=0.13.2->fiftyone) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /usr/local/lib/python3.12/dist-packages (from h2>=4.3.0->hypercorn<0.19,>=0.13.2->fiftyone) (4.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.10.0->universal-analytics-python3<2,>=1.0.1->fiftyone) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.10.0->universal-analytics-python3<2,>=1.0.1->fiftyone) (1.0.9)
# Collecting bcrypt>=3.2 (from paramiko<4,>=3->voxel51-eta<0.16,>=0.15.3->fiftyone)
#   Downloading bcrypt-5.0.0-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: cryptography>=3.3 in /usr/local/lib/python3.12/dist-packages (from paramiko<4,>=3->voxel51-eta<0.16,>=0.15.3->fiftyone) (43.0.3)
# Collecting pynacl>=1.5 (from paramiko<4,>=3->voxel51-eta<0.16,>=0.15.3->fiftyone)
#   Downloading pynacl-1.6.2-cp38-abi3-manylinux_2_34_x86_64.whl.metadata (10.0 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib<4->fiftyone) (1.17.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonlines->voxel51-eta<0.16,>=0.15.3->fiftyone) (26.1.0)
# Collecting texttable (from py7zr->voxel51-eta<0.16,>=0.15.3->fiftyone)
#   Downloading texttable-1.7.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: pycryptodomex>=3.20.0 in /usr/local/lib/python3.12/dist-packages (from py7zr->voxel51-eta<0.16,>=0.15.3->fiftyone) (3.23.0)
# Requirement already satisfied: brotli>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from py7zr->voxel51-eta<0.16,>=0.15.3->fiftyone) (1.2.0)
# Collecting backports.zstd>=1.0.0 (from py7zr->voxel51-eta<0.16,>=0.15.3->fiftyone)
#   Downloading backports_zstd-1.3.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (6.9 kB)
# Collecting pyppmd>=1.3.1 (from py7zr->voxel51-eta<0.16,>=0.15.3->fiftyone)
#   Downloading pyppmd-1.3.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Collecting pybcj>=1.0.6 (from py7zr->voxel51-eta<0.16,>=0.15.3->fiftyone)
#   Downloading pybcj-1.0.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.9 kB)
# Collecting multivolumefile>=0.2.3 (from py7zr->voxel51-eta<0.16,>=0.15.3->fiftyone)
#   Downloading multivolumefile-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Collecting inflate64>=1.0.4 (from py7zr->voxel51-eta<0.16,>=0.15.3->fiftyone)
#   Downloading inflate64-1.0.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->voxel51-eta<0.16,>=0.15.3->fiftyone) (3.4.6)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=3.3->paramiko<4,>=3->voxel51-eta<0.16,>=0.15.3->fiftyone) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=3.3->paramiko<4,>=3->voxel51-eta<0.16,>=0.15.3->fiftyone) (3.0)
# Downloading fiftyone-1.14.0-py3-none-any.whl (17.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.7/17.7 MB 95.9 MB/s eta 0:00:00
# Downloading argcomplete-3.6.3-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 5.0 MB/s eta 0:00:00
# Downloading async_lru-2.3.0-py3-none-any.whl (8.4 kB)
# Downloading boto3-1.42.82-py3-none-any.whl (140 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 18.6 MB/s eta 0:00:00
# Downloading dacite-1.9.2-py3-none-any.whl (16 kB)
# Downloading exceptiongroup-1.3.1-py3-none-any.whl (16 kB)
# Downloading fiftyone_brain-0.21.5-py3-none-any.whl (112 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.8/112.8 kB 14.8 MB/s eta 0:00:00
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 5.7 MB/s eta 0:00:00
# Downloading hypercorn-0.18.0-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 7.6 MB/s eta 0:00:00
# Downloading mongoengine-0.29.3-py3-none-any.whl (112 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.5/112.5 kB 15.1 MB/s eta 0:00:00
# Downloading motor-3.6.1-py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.8/74.8 kB 9.6 MB/s eta 0:00:00
# Downloading plotly-6.6.0-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 120.0 MB/s eta 0:00:00
# Downloading pprintpp-0.4.0-py2.py3-none-any.whl (16 kB)
# Downloading pydash-8.0.6-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 13.5 MB/s eta 0:00:00
# Downloading pymongo-4.9.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 93.7 MB/s eta 0:00:00
# Downloading retrying-1.4.2-py3-none-any.whl (10 kB)
# Downloading sseclient_py-1.9.0-py3-none-any.whl (8.4 kB)
# Downloading strawberry_graphql-0.291.3-py3-none-any.whl (316 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.4/316.4 kB 36.1 MB/s eta 0:00:00
# Downloading universal_analytics_python3-1.1.1-py3-none-any.whl (10 kB)
# Downloading voxel51_eta-0.15.4-py2.py3-none-any.whl (934 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 934.6/934.6 kB 65.1 MB/s eta 0:00:00
# Downloading xmltodict-1.0.4-py3-none-any.whl (13 kB)
# Downloading deprecated-1.3.1-py2.py3-none-any.whl (11 kB)
# Downloading botocore-1.42.82-py3-none-any.whl (14.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 104.1 MB/s eta 0:00:00
# Downloading cross_web-0.4.1-py3-none-any.whl (14 kB)
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 35.6 MB/s eta 0:00:00
# Downloading graphql_core-3.2.8-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 25.8 MB/s eta 0:00:00
# Downloading jmespath-1.1.0-py3-none-any.whl (20 kB)
# Downloading paramiko-3.5.1-py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.3/227.3 kB 27.8 MB/s eta 0:00:00
# Downloading s3transfer-0.16.0-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 11.2 MB/s eta 0:00:00
# Downloading wsproto-1.3.2-py3-none-any.whl (24 kB)
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Downloading priority-2.0.0-py3-none-any.whl (8.9 kB)
# Downloading py7zr-1.1.0-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.3/71.3 kB 9.1 MB/s eta 0:00:00
# Downloading rarfile-4.2-py3-none-any.whl (29 kB)
# Downloading backports_zstd-1.3.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (494 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.2/494.2 kB 48.7 MB/s eta 0:00:00
# Downloading bcrypt-5.0.0-cp39-abi3-manylinux_2_34_x86_64.whl (278 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 31.7 MB/s eta 0:00:00
# Downloading inflate64-1.0.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (100 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.6/100.6 kB 12.9 MB/s eta 0:00:00
# Downloading multivolumefile-0.2.3-py3-none-any.whl (17 kB)
# Downloading pybcj-1.0.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.5/51.5 kB 6.5 MB/s eta 0:00:00
# Downloading pynacl-1.6.2-cp38-abi3-manylinux_2_34_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 70.6 MB/s eta 0:00:00
# Downloading pyppmd-1.3.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.3/144.3 kB 18.4 MB/s eta 0:00:00
# Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Building wheels for collected packages: fiftyone-db
#   Building wheel for fiftyone-db (pyproject.toml) ... done
#   Created wheel for fiftyone-db: filename=fiftyone_db-1.4.1-py3-none-manylinux1_x86_64.whl size=50655255 sha256=1155c0bee8096434f7afd247026f3bac3cf6b8cee62fd756022d8bb1e7c84c6a
#   Stored in directory: /root/.cache/pip/wheels/fc/06/06/0eb7530b99c4934bf36390769cff3f0052fd04f50f390d5c8b
# Successfully built fiftyone-db
# Installing collected packages: texttable, pprintpp, xmltodict, wsproto, sseclient-py, retrying, rarfile, pyppmd, pydash, pybcj, priority, plotly, multivolumefile, jsonlines, jmespath, inflate64, graphql-core, ftfy, fiftyone-db, exceptiongroup, dnspython, Deprecated, dacite, cross-web, bcrypt, backports.zstd, async_lru, argcomplete, strawberry-graphql, pynacl, pymongo, py7zr, hypercorn, botocore, universal-analytics-python3, s3transfer, paramiko, motor, mongoengine, fiftyone-brain, voxel51-eta, boto3, fiftyone
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.24.1
#     Uninstalling plotly-5.24.1:
#       Successfully uninstalled plotly-5.24.1
# Successfully installed Deprecated-1.3.1 argcomplete-3.6.3 async_lru-2.3.0 backports.zstd-1.3.0 bcrypt-5.0.0 boto3-1.42.82 botocore-1.42.82 cross-web-0.4.1 dacite-1.9.2 dnspython-2.8.0 exceptiongroup-1.3.1 fiftyone-1.14.0 fiftyone-brain-0.21.5 fiftyone-db-1.4.1 ftfy-6.3.1 graphql-core-3.2.8 hypercorn-0.18.0 inflate64-1.0.4 jmespath-1.1.0 jsonlines-4.0.0 mongoengine-0.29.3 motor-3.6.1 multivolumefile-0.2.3 paramiko-3.5.1 plotly-6.6.0 pprintpp-0.4.0 priority-2.0.0 py7zr-1.1.0 pybcj-1.0.7 pydash-8.0.6 pymongo-4.9.2 pynacl-1.6.2 pyppmd-1.3.1 rarfile-4.2 retrying-1.4.2 s3transfer-0.16.0 sseclient-py-1.9.0 strawberry-graphql-0.291.3 texttable-1.7.0 universal-analytics-python3-1.1.1 voxel51-eta-0.15.4 wsproto-1.3.2 xmltodict-1.0.4

# %%
import fiftyone as fo

fo.config.requirement_error_level=2
# Out:
# /usr/local/lib/python3.12/dist-packages/glob2/fnmatch.py:141: SyntaxWarning: invalid escape sequence '\Z'
#   return '(?ms)' + res + '\Z'

# %% [markdown]
# ---
# ## Section 1: What We Were Given
#
# Before running any models, let's understand the shape of what we have.
#
# The Action100M preview comes with rich pre-existing annotations from the Tree-of-Captions pipeline. Each video has temporal segments annotated at multiple levels of granularity:
#
# - **Level 0 (root/tier):** The full video — one annotation covering the entire 90-second clip
# - **Mid levels:** Sub-segments — multi-second chunks describing coherent activities
# - **Leaf level:** The finest grain — individual moments
#
# At each level, there are five annotation fields:
# - `gpt_summary_brief` — one-sentence clip caption
# - `gpt_summary_detailed` — full play-by-play description
# - `gpt_action_brief` — short verb phrase ("spread almonds on tray")
# - `gpt_action_detailed` — instruction-manual version of the action
# - `gpt_action_actor` — who's performing it
#
# All of these were generated by GPT-OSS-120B with three rounds of Self-Refine. We're going to take these at face value for now — and then build the tools to interrogate them.
#
# You can either download the dataset from the [Voxel51 Hugging Face org](https://huggingface.co/datasets/Voxel51/action100m_tiny_subset), or if you face rate limit issues, you can follow the instructions in the `download_scripts` directory of this repository to download the dataset and parse it into FiftyOne format.
#
# If you are downloading from the Hugging Face Hub, run:
#
# ```python
# from fiftyone.utils.huggingface import load_from_hub
#
# dataset = load_from_hub(
#     "Voxel51/action100m_tiny_subset",
#     dataset_name="action100m",
#     overwrite=True,
#     persistent=True,
# )
# ```
#
# If you wat to use the dataset with all the enrichments, then run:
#
# ```python
# from fiftyone.utils.huggingface import load_from_hub
#
# dataset = load_from_hub(
#     "harpreetsahota/fo_video_workshop_enriched",
#     dataset_name="action100m_enriched",
#     overwrite=True,
#     persistent=True,
# )
# ```
#
# If you've downloaded the dataset and parsed manually, then run:
#
# ```python
# dataset = fo.load_dataset("action100m")
# ```
#
# I will assume that you'll want the datasets with all the enrichments:

# %%
import fiftyone as fo
from fiftyone.utils.huggingface import load_from_hub

dataset = load_from_hub(
    "harpreetsahota/fo_video_workshop_enriched",
    dataset_name="action100m_enriched",
    overwrite=True,
    persistent=True,
)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Downloading config file fiftyone.yml from harpreetsahota/fo_video_workshop_enriched
# INFO:fiftyone.utils.huggingface:Downloading config file fiftyone.yml from harpreetsahota/fo_video_workshop_enriched
# fiftyone.yml:   0%|          | 0.00/120 [00:00<?, ?B/s]
# Loading dataset
# INFO:fiftyone.utils.huggingface:Loading dataset
# Importing samples...
# INFO:fiftyone.utils.data.importers:Importing samples...
#  100% |███████████████| 1144/1144 [1.6s elapsed, 0s remaining, 721.7 samples/s]
# INFO:eta.core.utils: 100% |███████████████| 1144/1144 [1.6s elapsed, 0s remaining, 721.7 samples/s]
# Importing frames...
# INFO:fiftyone.utils.data.importers:Importing frames...
#  100% |█████████████████████| 0/0 [1.7ms elapsed, ? remaining, ? samples/s]
# INFO:eta.core.utils: 100% |█████████████████████| 0/0 [1.7ms elapsed, ? remaining, ? samples/s]
# Downloading 1144 media files...
# INFO:fiftyone.utils.huggingface:Downloading 1144 media files...
# 100%|██████████| 12/12 [02:11<00:00, 10.94s/it]

# %% [markdown]
# A **[FiftyOne dataset](https://docs.voxel51.com/user_guide/using_datasets.html)** is the core data structure you work with in [FiftyOne](https://docs.voxel51.com/user_guide/basics.html). It:
#
# - Logically represents your visual data (images, videos, point clouds, etc.) along with all associated information: labels, metadata, predictions, and other fields.
#
# - Is stored in a lightweight, non-relational database (MongoDB) so it can scale to large datasets without loading all media into RAM.
#
# - Can be created from many sources: directories of files, common dataset formats (like COCO), or the built‑in Dataset Zoo.
#
# Conceptually, you can [think of a dataset like a table in pandas](https://github.com/voxel51/fiftyone/blob/develop/docs/source/tutorials/pandas_comparison.ipynb): it has **rows and columns**, but specialized for computer vision:
#
# - In pandas: **row = record**, **column = feature**
# - In FiftyOne: **sample = record**, **field = feature**
#
# You can inspect the schema of a dataset by calling it:

# %%
dataset
# Out:
# Name:        harpreetsahota/fo_video_workshop_enriched
# Media type:  video
# Num samples: 1144
# Persistent:  True
# Tags:        []
# Sample fields:
#     id:                                        fiftyone.core.fields.ObjectIdField
#     filepath:                                  fiftyone.core.fields.StringField
#     tags:                                      fiftyone.core.fields.ListField(fiftyone.core.fields.StringField)
#     metadata:                                  fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.metadata.VideoMetadata)
#     created_at:                                fiftyone.core.fields.DateTimeField
#     last_modified_at:                          fiftyone.core.fields.DateTimeField
#     title:                                     fiftyone.core.fields.StringField
#     description:                               fiftyone.core.fields.StringField
#     full_video_url:                            fiftyone.core.fields.StringField
#     upload_date:                               fiftyone.core.fields.DateTimeField
#     view_count:                                fiftyone.core.fields.IntField
#     like_count:                                fiftyone.core.fields.IntField
#     full_video_duration:                       fiftyone.core.fields.IntField
#     transcript:                                fiftyone.core.fields.StringField
#     tree_depth:                                fiftyone.core.fields.IntField
#     gpt_summary_brief:                         fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.TemporalDetections)
#     gpt_summary_detailed:                      fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.TemporalDetections)
#     gpt_action_brief:                          fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.TemporalDetections)
#     gpt_action_detailed:                       fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.TemporalDetections)
#     gpt_action_actor:                          fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.TemporalDetections)
#     transcript_segments:                       fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.TemporalDetections)
#     qwen_embeddings:                           fiftyone.core.fields.VectorField
#     predicted_class:                           fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Classification)
#     molmo_embeddings:                          fiftyone.core.fields.VectorField
#     text_embeddings:                           fiftyone.core.fields.VectorField
#     qwen_uniqueness:                           fiftyone.core.fields.FloatField
#     qwen_rep:                                  fiftyone.core.fields.FloatField
#     qwen_desc_summary:                         fiftyone.core.fields.StringField
#     qwen_events_events:                        fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.TemporalDetections)
#     qwen_comp_summary:                         fiftyone.core.fields.StringField
#     qwen_comp_objects:                         fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.TemporalDetections)
#     qwen_comp_events:                          fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.TemporalDetections)
#     qwen_comp_text_content:                    fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.TemporalDetections)
#     qwen_comp_scene_info_setting:              fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Classification)
#     qwen_comp_scene_info_time_of_day:          fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Classification)
#     qwen_comp_scene_info_location_type:        fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Classification)
#     qwen_comp_activities_primary_activity:     fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Classification)
#     qwen_comp_activities_secondary_activities: fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Classifications)
#     qwen_custom_result:                        fiftyone.core.fields.StringField
#     molmo_custom_description:                  fiftyone.core.fields.StringField
# Frame fields:
#     id:               fiftyone.core.fields.ObjectIdField
#     frame_number:     fiftyone.core.fields.FrameNumberField
#     created_at:       fiftyone.core.fields.DateTimeField
#     last_modified_at: fiftyone.core.fields.DateTimeField

# %% [markdown]
# ### What is a sample?
#
# A [**sample**](https://docs.voxel51.com/user_guide/basics.html#samples) is the atomic element of a FiftyOne dataset. It is:
#
# - One “item” of your data (for example, a single image or a single video) plus everything you know about it.
# - A flexible container of [**fields**](https://docs.voxel51.com/user_guide/basics.html#fields), which can include:
#   - `filepath` to the media
#   - `metadata` (dimensions, duration, etc.)
#   - Ground truth labels (detections, classifications, segmentations, etc.)
#   - Model predictions
#   - Tags, scalar values, strings, arrays, and more
#
# So, **a dataset is a collection of samples**, and **each sample is everything you care about for one media file**, stored in a structured way that’s easy to query, visualize, and modify.
#
# You can see what a sample looks like by inspecting the [first](https://docs.voxel51.com/api/fiftyone.core.dataset.html#fiftyone.core.dataset.Dataset.first) sample:

# %%
dataset.first()
# Out:
# <Sample: {
#     'id': '698d1a6e5a33217ed940605c',
#     'media_type': 'video',
#     'filepath': '/root/fiftyone/huggingface/hub/harpreetsahota/fo_video_workshop_enriched/data/-P30ESZQL2A.mp4',
#     'tags': [],
#     'metadata': <VideoMetadata: {
#         'size_bytes': 5295732,
#         'mime_type': 'video/mp4',
#         'frame_width': 640,
#         'frame_height': 360,
#         'frame_rate': 29.97002997002997,
#         'total_frame_count': 2698,
#         'duration': 90.023267,
#         'encoding_str': 'avc1',
#     }>,
#     'created_at': datetime.datetime(2026, 4, 3, 14, 14, 50, 361000),
#     'last_modified_at': datetime.datetime(2026, 4, 3, 14, 14, 50, 361000),
#     'title': 'How To Soften New Dickies Pants | How To Make Pants Soft',
#     'description': 'I took a second to show you guys how I soften a new pair of Dickies pants.\n\nDickies Pants - http://amzn.to/1LBlApF\n\nKillFab Clothing Co. - https://www.killfab.com\n\nYou can always find me here:\nFacebook: thefabforums\nInstagram: @thefabforums\nTwitter: @thefabforums\nSnapChat Username: vossperformance\nwww.thefabforums.com',
#     'full_video_url': 'https://www.youtube.com/watch?v=-P30ESZQL2A',
#     'upload_date': datetime.datetime(2016, 3, 21, 0, 0),
#     'view_count': 222577,
#     'like_count': 1933,
#     'full_video_duration': 246,
#     'transcript': "[Music] quick  tip  I  just  recently  bought  some Dicky  pants  and  for  those  of  you  guys that  wear  Dickies  you  know  that  when  you get  them  they  pretty  much  stand  up  by themselves  they're  like  pleated  and super  hard  and  so  I  got  a  little  secret that  I  use  when  I  buy  these  things  uh  to loosen  them  up  all  right  so  I  just  got some  original  fit 874  these  things  brand  new  you  can  see they  got  a  big  pleat  down  the front  you  put  them  on  right  now  you  feel like  you  should  be  going  to  church  or something  like  super  stiff  like  a  dress pant  so  what  I  like  to  do  is  brine them  yep  if  you  like  to  cook  you  know what  a  Brian  is  and  yes  you  do  it  the same  exact  way  so  I  to  start  off  with the  5  gallon bucket  and  uh  fill  it  with  hot water  all  right  you  want  to  fill  it  with hot  water  and  the  reason  why  is  cuz you're  going  to  put  salt  in  it  okay  this is  eye  dye  salt  just  cheap  version  of under  a  buck  for  this  whole  thing  I  just",
#     'tree_depth': 12,
#     'gpt_summary_brief': <TemporalDetections: {
#         'detections': [
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c0d',
#                 'tags': [],
#                 'label': 'A man softens new Dickies pants by soaking them in a hot salt brine.',
#                 'support': [1, 2698],
#                 'confidence': None,
#                 'node_id': '311004b7-9e8b-5bbd-9eb5-a9f99544a938',
#                 'parent_id': None,
#                 'level': 0,
#                 'tier': 'root',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c12',
#                 'tags': [],
#                 'label': 'The presenter demonstrates how to soften a stiff new pair of Dickies pants using a hot salt‑water brine.',
#                 'support': [1, 2698],
#                 'confidence': None,
#                 'node_id': '19a1b2f1-da9f-5750-a597-18a69120bc1e',
#                 'parent_id': '311004b7-9e8b-5bbd-9eb5-a9f99544a938',
#                 'level': 1,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c17',
#                 'tags': [],
#                 'label': 'The clip begins with a garage scene of welding and a pickup‑truck, then moves to a kitchen where the presenter shows denim jeans and pours water from an orange bucket.',
#                 'support': [1, 1774],
#                 'confidence': None,
#                 'node_id': '1acc5b56-6d0a-540c-865d-ed575020b49b',
#                 'parent_id': '19a1b2f1-da9f-5750-a597-18a69120bc1e',
#                 'level': 2,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c1c',
#                 'tags': [],
#                 'label': 'The presenter fills an orange bucket with hot, salted water, submerges his new Dickies pants to soften them, lets the soak sit, then washes and dries the trousers before carrying the bucket to the garage.',
#                 'support': [1774, 2698],
#                 'confidence': None,
#                 'node_id': '1704fd80-4404-5876-98a4-9d3baae186b5',
#                 'parent_id': '19a1b2f1-da9f-5750-a597-18a69120bc1e',
#                 'level': 2,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c21',
#                 'tags': [],
#                 'label': 'Fabricators weld a partially built gray car in a busy workshop before the clip cuts to a yellow‑text title card.',
#                 'support': [1, 463],
#                 'confidence': None,
#                 'node_id': 'f3ff608b-7532-5310-b860-aec697b5cc0b',
#                 'parent_id': '1acc5b56-6d0a-540c-865d-ed575020b49b',
#                 'level': 3,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c26',
#                 'tags': [],
#                 'label': 'The presenter shows a stiff new pair of Dickies pants, explains a salt‑water brine softening method, and displays an orange bucket while speaking in a kitchen.',
#                 'support': [463, 1774],
#                 'confidence': None,
#                 'node_id': 'd3fd2a1b-00b1-59d0-aa7a-e0994e561308',
#                 'parent_id': '1acc5b56-6d0a-540c-865d-ed575020b49b',
#                 'level': 3,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c2b',
#                 'tags': [],
#                 'label': 'A man in black mixes water, white powder and a clear liquid in an orange bucket, stirs, then rinses the bucket.',
#                 'support': [1774, 2698],
#                 'confidence': None,
#                 'node_id': 'bd81d62a-f452-5c34-a853-0ea5988f66ae',
#                 'parent_id': '1704fd80-4404-5876-98a4-9d3baae186b5',
#                 'level': 3,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c30',
#                 'tags': [],
#                 'label': 'A man welds and cuts metal parts in a workshop while various tools and a car frame are shown.',
#                 'support': [1, 359],
#                 'confidence': None,
#                 'node_id': 'ec706049-c22e-5641-a4cd-37723d3fa547',
#                 'parent_id': 'f3ff608b-7532-5310-b860-aec697b5cc0b',
#                 'level': 4,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c35',
#                 'tags': [],
#                 'label': 'A man in a kitchen introduces a quick tip for softening new Dickies pants, gesturing as the camera moves from a close‑up of his face to a wider view of the room.',
#                 'support': [463, 963],
#                 'confidence': None,
#                 'node_id': 'a9db2bea-d356-5ccc-ae05-cf3119343606',
#                 'parent_id': 'd3fd2a1b-00b1-59d0-aa7a-e0994e561308',
#                 'level': 4,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c3a',
#                 'tags': [],
#                 'label': 'The presenter shows a pair of dark‑grey pants, then a black bag, and finally lifts an orange bucket while standing in a bright kitchen.',
#                 'support': [963, 1774],
#                 'confidence': None,
#                 'node_id': '159cba67-268d-549c-84bc-7f7161a1297d',
#                 'parent_id': 'd3fd2a1b-00b1-59d0-aa7a-e0994e561308',
#                 'level': 4,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c3f',
#                 'tags': [],
#                 'label': 'A man fills a bucket with hot water, adds salt and other powders, mixes the solution, and then pumps the liquid out.',
#                 'support': [1774, 2698],
#                 'confidence': None,
#                 'node_id': '121e35d3-271c-581e-ba02-d7cf7f4852b7',
#                 'parent_id': 'bd81d62a-f452-5c34-a853-0ea5988f66ae',
#                 'level': 4,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c44',
#                 'tags': [],
#                 'label': 'A man welds on a partially assembled white car in a workshop.',
#                 'support': [1, 158],
#                 'confidence': None,
#                 'node_id': '395546d0-78d6-55c3-bb47-da4cbd69b70d',
#                 'parent_id': 'ec706049-c22e-5641-a4cd-37723d3fa547',
#                 'level': 5,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c49',
#                 'tags': [],
#                 'label': 'A male welder joins metal parts in a garage while brief shots show a vehicle wheel and a finished weld labeled “theFadFormation.”',
#                 'support': [158, 359],
#                 'confidence': None,
#                 'node_id': 'cc82ec91-1e2e-5c3a-8c6e-6bd19e7417d1',
#                 'parent_id': 'ec706049-c22e-5641-a4cd-37723d3fa547',
#                 'level': 5,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c4e',
#                 'tags': [],
#                 'label': 'Man in a kitchen introduces a quick tip for softening new Dickies pants.',
#                 'support': [518, 963],
#                 'confidence': None,
#                 'node_id': '99fbd398-d4ae-5ede-9152-733623ad3248',
#                 'parent_id': 'a9db2bea-d356-5ccc-ae05-cf3119343606',
#                 'level': 5,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c53',
#                 'tags': [],
#                 'label': 'A bearded man in a kitchen showcases a pair of black 874 Original Fit pants.',
#                 'support': [963, 1295],
#                 'confidence': None,
#                 'node_id': '47076e10-447a-5153-9b71-e21fd10f9a5a',
#                 'parent_id': '159cba67-268d-549c-84bc-7f7161a1297d',
#                 'level': 5,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c58',
#                 'tags': [],
#                 'label': 'The presenter examines jeans and pants, opens a black bag to show its size, then holds a glove, lifts an orange bucket and sprays a liquid onto the countertop.',
#                 'support': [1295, 1774],
#                 'confidence': None,
#                 'node_id': 'f396e88e-7f67-5a28-b652-de3645807d9a',
#                 'parent_id': '159cba67-268d-549c-84bc-7f7161a1297d',
#                 'level': 5,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c5d',
#                 'tags': [],
#                 'label': 'A man fills a bucket at the kitchen sink, pours several liquids into it, and demonstrates a paper‑towel holder.',
#                 'support': [1774, 2698],
#                 'confidence': None,
#                 'node_id': 'd5ed0a20-7b4b-552c-8c16-c47f4e9d7330',
#                 'parent_id': '121e35d3-271c-581e-ba02-d7cf7f4852b7',
#                 'level': 5,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c62',
#                 'tags': [],
#                 'label': 'A welder uses a plasma cutter on a workbench, shows fresh welds, and ends with a “The Fast Forward” logo.',
#                 'support': [223, 359],
#                 'confidence': None,
#                 'node_id': 'cdbc68a8-31cf-5d89-888e-807303eeb946',
#                 'parent_id': 'cc82ec91-1e2e-5c3a-8c6e-6bd19e7417d1',
#                 'level': 6,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c67',
#                 'tags': [],
#                 'label': 'A man in a brightly lit kitchen talks to the camera while gesturing, surrounded by white cabinets and appliances.',
#                 'support': [518, 675],
#                 'confidence': None,
#                 'node_id': '2cf0bf54-2296-5555-95f9-50daa2fa0a44',
#                 'parent_id': '99fbd398-d4ae-5ede-9152-733623ad3248',
#                 'level': 6,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c6c',
#                 'tags': [],
#                 'label': 'A bearded man in a kitchen talks to the camera and gestures with his hands.',
#                 'support': [675, 963],
#                 'confidence': None,
#                 'node_id': '1a0cb318-7d03-529b-ace0-ff459efdcdf4',
#                 'parent_id': '99fbd398-d4ae-5ede-9152-733623ad3248',
#                 'level': 6,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c71',
#                 'tags': [],
#                 'label': 'A man in a kitchen holds up a pair of black Dickies pants and flips them to reveal both sides.',
#                 'support': [1014, 1295],
#                 'confidence': None,
#                 'node_id': '5337e319-ce45-530f-a38a-67a543390bc6',
#                 'parent_id': '47076e10-447a-5153-9b71-e21fd10f9a5a',
#                 'level': 6,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c76',
#                 'tags': [],
#                 'label': 'The presenter shows a pair of pants and then opens a black shoe‑bag to display its interior in his kitchen.',
#                 'support': [1295, 1638],
#                 'confidence': None,
#                 'node_id': '2cb2aa0f-bfd0-5409-b61b-cc6cd3035d60',
#                 'parent_id': 'f396e88e-7f67-5a28-b652-de3645807d9a',
#                 'level': 6,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c7b',
#                 'tags': [],
#                 'label': 'The presenter explains a step while pointing, then lifts an orange bucket and sprays liquid onto the countertop.',
#                 'support': [1638, 1774],
#                 'confidence': None,
#                 'node_id': '4a4ed372-4fc2-5418-9bd7-81521b80ad1d',
#                 'parent_id': 'f396e88e-7f67-5a28-b652-de3645807d9a',
#                 'level': 6,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c80',
#                 'tags': [],
#                 'label': 'Man fills a red bucket with water at the kitchen sink, adds salt and other items, then handles the bucket and a canister.',
#                 'support': [1774, 2567],
#                 'confidence': None,
#                 'node_id': 'df13d614-c82a-523f-8eca-a8026261ea23',
#                 'parent_id': 'd5ed0a20-7b4b-552c-8c16-c47f4e9d7330',
#                 'level': 6,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c85',
#                 'tags': [],
#                 'label': 'The presenter pours the contents of a blue‑white labeled can into a large orange bowl on the kitchen counter.',
#                 'support': [2567, 2698],
#                 'confidence': None,
#                 'node_id': 'afebf5e9-8c64-5ff2-87cb-a93cb4fe04c0',
#                 'parent_id': 'd5ed0a20-7b4b-552c-8c16-c47f4e9d7330',
#                 'level': 6,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c8a',
#                 'tags': [],
#                 'label': 'A welder in a red mask and gloves lowers a torch onto a silver metal piece, creating a bright weld as the title “theFadFormation” flashes on screen.',
#                 'support': [238, 359],
#                 'confidence': None,
#                 'node_id': 'e20ad171-659a-543d-ac64-1ab08aa4858d',
#                 'parent_id': 'cdbc68a8-31cf-5d89-888e-807303eeb946',
#                 'level': 7,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c8f',
#                 'tags': [],
#                 'label': 'A man in a kitchen talks to the camera while gesturing.',
#                 'support': [518, 646],
#                 'confidence': None,
#                 'node_id': 'a0102f4b-844c-5e17-ab9b-cf7afd94ee45',
#                 'parent_id': '2cf0bf54-2296-5555-95f9-50daa2fa0a44',
#                 'level': 7,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c94',
#                 'tags': [],
#                 'label': 'A bearded man in a black t‑shirt, cap and glasses talks to the camera while gesturing inside a kitchen.',
#                 'support': [675, 879],
#                 'confidence': None,
#                 'node_id': '60371226-7813-54d4-bf7b-66afc9f590c9',
#                 'parent_id': '1a0cb318-7d03-529b-ace0-ff459efdcdf4',
#                 'level': 7,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c99',
#                 'tags': [],
#                 'label': 'A bearded man in a black T‑shirt and baseball cap displays a pair of black pants in his kitchen.',
#                 'support': [1094, 1295],
#                 'confidence': None,
#                 'node_id': '6ca8e034-9c27-5008-a52f-291e05c92c5c',
#                 'parent_id': '5337e319-ce45-530f-a38a-67a543390bc6',
#                 'level': 7,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c9e',
#                 'tags': [],
#                 'label': 'Man opens a shoe bag to show the shoes inside.',
#                 'support': [1406, 1638],
#                 'confidence': None,
#                 'node_id': '242ea31a-f85b-5011-ba8d-86b940f16e45',
#                 'parent_id': '2cb2aa0f-bfd0-5409-b61b-cc6cd3035d60',
#                 'level': 7,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400ca3',
#                 'tags': [],
#                 'label': 'A man fills a large bucket with water, rinses a red plastic container, and pours its water into a white container at a kitchen sink.',
#                 'support': [1774, 2086],
#                 'confidence': None,
#                 'node_id': '796f46ff-8f36-590c-9546-00e958630f29',
#                 'parent_id': 'df13d614-c82a-523f-8eca-a8026261ea23',
#                 'level': 7,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400ca8',
#                 'tags': [],
#                 'label': 'A man pours water into an orange bucket at the kitchen sink and then lifts a blue‑labeled canister from beneath the bucket.',
#                 'support': [2086, 2567],
#                 'confidence': None,
#                 'node_id': '1a8d442d-9fbb-5c38-a4cf-64f39d0b726d',
#                 'parent_id': 'df13d614-c82a-523f-8eca-a8026261ea23',
#                 'level': 7,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400cad',
#                 'tags': [],
#                 'label': 'The man holds up several containers and a roll of paper towels while speaking at his kitchen sink.',
#                 'support': [2567, 2698],
#                 'confidence': None,
#                 'node_id': 'b0a22ad7-ae21-58a7-860d-1fb21c6f4607',
#                 'parent_id': 'afebf5e9-8c64-5ff2-87cb-a93cb4fe04c0',
#                 'level': 7,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400cb2',
#                 'tags': [],
#                 'label': 'A man in a kitchen talks to the camera while gesturing with his right hand.',
#                 'support': [675, 814],
#                 'confidence': None,
#                 'node_id': '72ec3314-193e-57c5-a8a2-55f45eeb4768',
#                 'parent_id': '60371226-7813-54d4-bf7b-66afc9f590c9',
#                 'level': 8,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400cb7',
#                 'tags': [],
#                 'label': 'Man opens a black bag and lifts it out of the frame in a bright kitchen.',
#                 'support': [1406, 1563],
#                 'confidence': None,
#                 'node_id': 'b0ab596c-701f-5a97-9f8c-c60508080b06',
#                 'parent_id': '242ea31a-f85b-5011-ba8d-86b940f16e45',
#                 'level': 8,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400cbc',
#                 'tags': [],
#                 'label': 'Man rinses a red plastic container at the kitchen sink and pours its water into a white container.',
#                 'support': [1830, 2086],
#                 'confidence': None,
#                 'node_id': '130cec78-6609-52e6-a738-741d2c6b9ccd',
#                 'parent_id': '796f46ff-8f36-590c-9546-00e958630f29',
#                 'level': 8,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400cc1',
#                 'tags': [],
#                 'label': 'A man in a black T‑shirt and baseball cap pours liquid from a white cup into a red bucket at the kitchen sink.',
#                 'support': [2086, 2287],
#                 'confidence': None,
#                 'node_id': 'cfc0a863-d765-56c7-9ce2-ea0eb8fcb2ad',
#                 'parent_id': '1a8d442d-9fbb-5c38-a4cf-64f39d0b726d',
#                 'level': 8,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400cc6',
#                 'tags': [],
#                 'label': 'A man pours liquid into an orange bucket, rubs its rim, and lifts a canister from underneath it.',
#                 'support': [2287, 2567],
#                 'confidence': None,
#                 'node_id': '833ab7b9-4bb6-5cd8-944c-024ad843b621',
#                 'parent_id': '1a8d442d-9fbb-5c38-a4cf-64f39d0b726d',
#                 'level': 8,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400ccb',
#                 'tags': [],
#                 'label': 'A man fills a red bucket with water at the kitchen sink.',
#                 'support': [1830, 2038],
#                 'confidence': None,
#                 'node_id': 'e3053483-c476-50c2-9e9b-4c0a9dccc1a0',
#                 'parent_id': '130cec78-6609-52e6-a738-741d2c6b9ccd',
#                 'level': 9,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400cd0',
#                 'tags': [],
#                 'label': 'Man runs his hands over an orange bucket, then lifts, tilts, and lowers a blue‑labelled canister.',
#                 'support': [2318, 2567],
#                 'confidence': None,
#                 'node_id': '935f281d-3629-5551-b6e2-0a6e03d09e45',
#                 'parent_id': '833ab7b9-4bb6-5cd8-944c-024ad843b621',
#                 'level': 9,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400cd5',
#                 'tags': [],
#                 'label': 'A man fills a bucket with water from the kitchen faucet.',
#                 'support': [1902, 2038],
#                 'confidence': None,
#                 'node_id': 'bec92c34-d2a8-5ea5-af0b-6e66ca412e11',
#                 'parent_id': 'e3053483-c476-50c2-9e9b-4c0a9dccc1a0',
#                 'level': 10,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400cda',
#                 'tags': [],
#                 'label': 'The man washes dishes, lifts an orange bowl, and gestures while talking in his kitchen.',
#                 'support': [2318, 2510],
#                 'confidence': None,
#                 'node_id': 'baa1b672-3981-58af-8415-159d6cfff392',
#                 'parent_id': '935f281d-3629-5551-b6e2-0a6e03d09e45',
#                 'level': 10,
#                 'tier': 'mid',
#             }>,
#         ],
#     }>,
#     'gpt_summary_detailed': <TemporalDetections: {
#         'detections': [
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c0e',
#                 'tags': [],
#                 'label': 'The video begins with a man standing in a kitchen, explaining that new Dickies pants are extremely stiff. He fills a large orange 5‑gallon bucket with hot water, adds a generous amount of salt and stirs until the salt dissolves. He places the pants—wrapped in a black plastic bag—into the bucket so they are fully submerged, then lets the bucket sit for a day or two. After the soaking period he removes the bagged pants, rinses them, washes them in the laundry and lets them dry, demonstrating the pants now feel much softer. The scene then cuts to him outdoors beside the same bucket, where he drops the bucket onto the gravel, and finally to a garage where he handles the bucket again while a black dog wanders in the background.',
#                 'support': [1, 2698],
#                 'confidence': None,
#                 'node_id': '311004b7-9e8b-5bbd-9eb5-a9f99544a938',
#                 'parent_id': None,
#                 'level': 0,
#                 'tier': 'root',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c13',
#                 'tags': [],
#                 'label': 'The video opens with the presenter holding a brand‑new pair of Dickies pants, pointing out how stiff and heavily pleated they are straight out of the package. He explains that a simple brine can loosen the fabric. Using a large orange bucket, he fills it with hot water from the kitchen faucet, adds a generous amount of salt and stirs until most of the salt dissolves. He then fully submerges the pants in the salty water, covers the bucket and lets the pants soak for a day or two. After the soaking period he drains the bucket, rinses the pants, runs them through a regular wash cycle, and shows the now‑softened, more comfortable pants. The segment ends with a brief outro.',
#                 'support': [1, 2698],
#                 'confidence': None,
#                 'node_id': '19a1b2f1-da9f-5750-a597-18a69120bc1e',
#                 'parent_id': '311004b7-9e8b-5bbd-9eb5-a9f99544a938',
#                 'level': 1,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c18',
#                 'tags': [],
#                 'label': 'The first few seconds show a garage workspace: a person welds a metal piece while another person opens a pickup‑truck door and pulls a cloth from the doorway. A brief cut shows three men in black shirts moving their arms and legs, with a flashing yellow logo on a dark background. The view then cuts to a brightly lit kitchen. A bearded man wearing a black T‑shirt and a black baseball cap leans on the white‑capped countertop, talks to the camera, and lifts a pair of dark denim jeans with both hands, shaking them to display the tags and front pockets. He then picks up an orange bucket with his left hand, bends slightly, and tips the bucket to let water flow out while keeping his right hand free. The segment ends with him still holding the bucket, slightly hunched over the counter.',
#                 'support': [1, 1774],
#                 'confidence': None,
#                 'node_id': '1acc5b56-6d0a-540c-865d-ed575020b49b',
#                 'parent_id': '19a1b2f1-da9f-5750-a597-18a69120bc1e',
#                 'level': 2,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c1d',
#                 'tags': [],
#                 'label': 'Standing at a kitchen sink, the man lifts a large orange bucket, turns on the hot faucet and lets water fill the bucket. He pours a generous amount of white salt from a small container into the water, then adds a few black‑capped bottles and stirs the mixture with a long‑handled brush. He places the new Dickies trousers into the bucket, making sure they are fully covered, and leaves the bucket to soak for an extended period (shown as overnight). After the soak, he removes the pants, wrings out excess liquid, washes them in the laundry, and sets them out to dry. He then carries the bucket out of the kitchen, walks through a doorway into a garage, points toward the camera, dips both hands into the bucket, and finally sets the bucket down near the garage entrance. The final moments show him standing beside a car, briefly interacting with a black dog that wanders nearby.',
#                 'support': [1774, 2698],
#                 'confidence': None,
#                 'node_id': '1704fd80-4404-5876-98a4-9d3baae186b5',
#                 'parent_id': '19a1b2f1-da9f-5750-a597-18a69120bc1e',
#                 'level': 2,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c22',
#                 'tags': [],
#                 'label': 'The segment opens on a bustling workshop where a gray, partially assembled car chassis sits in the centre, missing its front, roof and doors. To the right a metal piece is clamped in a bench vise, and two welders work in the background, each holding a torch that emits a bright purple arc of light and sparks. Shelves of tools, assorted equipment and four pictures hung on a long wall fill the background, emphasizing the industrial setting. After several seconds of this active welding scene, the footage abruptly transitions to a static black screen displaying the yellow lettering “THEFABFORUM.COM” in large font.',
#                 'support': [1, 463],
#                 'confidence': None,
#                 'node_id': 'f3ff608b-7532-5310-b860-aec697b5cc0b',
#                 'parent_id': '1acc5b56-6d0a-540c-865d-ed575020b49b',
#                 'level': 3,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c27',
#                 'tags': [],
#                 'label': 'In a well‑lit kitchen with white cabinets, granite countertops and black appliances, a bearded man wearing a black baseball cap and a black T‑shirt holds a dark‑grey pair of new Dickies pants, lifts them to show the interior white shirt and flips the pants to display both sides while noting how hard and pleated they are when fresh. He then picks up an orange bucket with his left hand, lifts and angles it toward the camera as he explains that the pants can be softened by soaking them in a hot‑water salt‑water brine made in a five‑gallon bucket.',
#                 'support': [463, 1774],
#                 'confidence': None,
#                 'node_id': 'd3fd2a1b-00b1-59d0-aa7a-e0994e561308',
#                 'parent_id': '1acc5b56-6d0a-540c-865d-ed575020b49b',
#                 'level': 3,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c2c',
#                 'tags': [],
#                 'label': 'Standing at the kitchen sink, a man wearing a black T‑shirt and baseball cap places an orange plastic bucket under the faucet and runs hot water into it. He pours a white powder (salt) into the water, adds a clear liquid from a bottle, and uses a brush to stir the mixture, repeating the addition and stirring a few times. He then lifts the bucket by its black handle and moves it away from the sink. Later he returns, fills the bucket with water again, dips the brush into the bucket to agitate the solution, rinses the bucket under the running water, tilts it to drain, and finally carries the bucket away.',
#                 'support': [1774, 2698],
#                 'confidence': None,
#                 'node_id': 'bd81d62a-f452-5c34-a853-0ea5988f66ae',
#                 'parent_id': '1704fd80-4404-5876-98a4-9d3baae186b5',
#                 'level': 3,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c31',
#                 'tags': [],
#                 'label': 'The segment opens with a still image of a partially built hot‑rod frame in a garage, exposing the chassis and a front tire. It then shows a man in jeans, a black shirt, gloves and a welding helmet working on a white vehicle. He operates a blue Miller welding machine that sparks onto a metal piece, uses a grinder on a yellow‑painted column, and manipulates a large yellow workstation while a white car stands nearby. The scene shifts to short clips of the same man welding near a hydraulic press with a white car in the background, then seated at a metal bench joining two pipes together. Following this, close‑up footage shows him using a plasma cutter on the workbench and several tight shots of the resulting welds. The segment ends with a close‑up of the finished metal piece bearing a yellow “The Fast Forward” emblem.',
#                 'support': [1, 359],
#                 'confidence': None,
#                 'node_id': 'ec706049-c22e-5641-a4cd-37723d3fa547',
#                 'parent_id': 'f3ff608b-7532-5310-b860-aec697b5cc0b',
#                 'level': 4,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c36',
#                 'tags': [],
#                 'label': 'The presenter, a bearded man wearing a black T‑shirt with white lettering and a black baseball cap, stands in a well‑lit kitchen with white cabinets, a brown granite countertop and stainless‑steel appliances. He looks directly into the camera, says he has a quick tip for softening new Dickies pants, and uses his hands to point and make small gestures. The shot begins with a close‑up of his face and gradually pulls back to show more of the kitchen background.',
#                 'support': [463, 963],
#                 'confidence': None,
#                 'node_id': 'a9db2bea-d356-5ccc-ae05-cf3119343606',
#                 'parent_id': 'd3fd2a1b-00b1-59d0-aa7a-e0994e561308',
#                 'level': 4,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c3b',
#                 'tags': [],
#                 'label': 'A bearded man wearing a black T‑shirt and a black baseball cap stands in a well‑lit kitchen with white cabinets, a refrigerator, a microwave and a window behind him. He first faces the camera holding a pair of dark‑grey Dickies pants, raises them to show the front and then flips them over to display the label on the back. He next picks up a black bag, opens it slightly to show its interior, and holds it briefly. Near the end of the segment he grabs an orange bucket with his left hand, lifts the bucket toward the camera and holds it steady while still looking at the viewer, ending the clip with the bucket in hand.',
#                 'support': [963, 1774],
#                 'confidence': None,
#                 'node_id': '159cba67-268d-549c-84bc-7f7161a1297d',
#                 'parent_id': 'd3fd2a1b-00b1-59d0-aa7a-e0994e561308',
#                 'level': 4,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c40',
#                 'tags': [],
#                 'label': 'Standing at a kitchen sink, the man places a large plastic bucket under the faucet and runs hot water into it. He pours the contents of a white measuring cup (salt) into the bucket, then adds additional powdered ingredients shown in a blue‑capped box (sugar, flour, etc.), shaking and stirring the bucket to combine everything. He later pours more powder from a shaker or bottle into the bucket, again shaking to incorporate it. Finally, he grips a hand‑pump placed in the bucket and depresses it several times to force the liquid out, sets the pump down and walks away.',
#                 'support': [1774, 2698],
#                 'confidence': None,
#                 'node_id': '121e35d3-271c-581e-ba02-d7cf7f4852b7',
#                 'parent_id': 'bd81d62a-f452-5c34-a853-0ea5988f66ae',
#                 'level': 4,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c45',
#                 'tags': [],
#                 'label': 'The segment opens with a view of a partially built hot‑rod style car, its metal frame and chassis exposed in a garage workshop. The camera then cuts to a man wearing a black shirt, a beanie, jeans and gloves standing beside the white vehicle. He operates a blue welding/angle‑grinder unit mounted on a yellow column, producing bright sparks that strike the metal workpiece he holds against the machine. Shelves, wires, a blue box and other tools fill the background, emphasizing the busy workshop environment.',
#                 'support': [1, 158],
#                 'confidence': None,
#                 'node_id': '395546d0-78d6-55c3-bb47-da4cbd69b70d',
#                 'parent_id': 'ec706049-c22e-5641-a4cd-37723d3fa547',
#                 'level': 5,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c4a',
#                 'tags': [],
#                 'label': 'The clip opens with a quick cut of a man in a garage wearing a welding helmet, gloves and a dark shirt, using a torch near a hydraulic press while a white car is visible in the background. It then shows him seated at a metal workbench welding two metal pipes together. A brief close‑up follows of the underside of a black vehicle wheel and its suspension components. The view returns to the welder, who leans over a work table in slow motion, the bright welding arc illuminating the joint and a blue pen lying nearby. The camera pulls back to reveal his gloved hands holding the torch, then focuses on a second weld. The segment ends with a close‑up of the completed welded piece as the title “theFadFormation” appears on screen.',
#                 'support': [158, 359],
#                 'confidence': None,
#                 'node_id': 'cc82ec91-1e2e-5c3a-8c6e-6bd19e7417d1',
#                 'parent_id': 'ec706049-c22e-5641-a4cd-37723d3fa547',
#                 'level': 5,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c4f',
#                 'tags': [],
#                 'label': 'Standing in a bright kitchen with white cabinets, a brown granite countertop and visible stainless‑steel appliances, a man wearing a black T‑shirt with white lettering and a backwards black baseball cap faces the camera. He explains that new Dickies pants are very stiff and have a large front pleat, then mentions that he has a quick secret to loosen them. While speaking he uses his left hand to gesture and point, maintaining eye contact throughout the segment.',
#                 'support': [518, 963],
#                 'confidence': None,
#                 'node_id': '99fbd398-d4ae-5ede-9152-733623ad3248',
#                 'parent_id': 'a9db2bea-d356-5ccc-ae05-cf3119343606',
#                 'level': 5,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c54',
#                 'tags': [],
#                 'label': 'In a well‑lit kitchen with white cabinets, a refrigerator, a window and curtains, a bearded young man wearing a black baseball cap, a black T‑shirt and glasses lifts a pair of black 874 Original Fit pants, shows the back label with the barcode, turns the pants left and right to display both sides, flips the waistband toward the camera, and briefly touches a leg while checking the tag and speaking to the viewer.',
#                 'support': [963, 1295],
#                 'confidence': None,
#                 'node_id': '47076e10-447a-5153-9b71-e21fd10f9a5a',
#                 'parent_id': '159cba67-268d-549c-84bc-7f7161a1297d',
#                 'level': 5,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c59',
#                 'tags': [],
#                 'label': 'A man in a black T‑shirt and baseball cap stands in a bright kitchen. He first holds up a pair of gray denim jeans and then a pair of black pants, looking at them for the camera. He then picks up a black bag with white and red markings, opens it and turns it around to display its interior and dimensions. Continuing his explanation, he holds a black oven glove in his left hand while pointing with his right. The scene cuts to him carrying an orange bucket toward the camera; he lifts the bucket, moves toward the countertop and uses a spray bottle to mist a liquid onto the surface.',
#                 'support': [1295, 1774],
#                 'confidence': None,
#                 'node_id': 'f396e88e-7f67-5a28-b652-de3645807d9a',
#                 'parent_id': '159cba67-268d-549c-84bc-7f7161a1297d',
#                 'level': 5,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c5e',
#                 'tags': [],
#                 'label': 'Wearing a black T‑shirt and baseball cap, the man picks up a red plastic bucket and places it under the kitchen faucet, turning the tap on to fill the bucket with water and then turning it off. He uses a clear cup to add more water, washes a red plastic container in the sink, and pours that water into a white plastic container. He then pours a small amount of dish‑soap from a bottle into an orange bowl on the counter, runs his hands along the bucket’s rim, lifts a small canister from beneath the bucket and tilts it. Next, he shows how to insert a roll of paper towels into a holder and adjusts the holder. Afterward he lifts a white‑blue labelled container, raises and lowers it while speaking, and finally pours a white cleaning solution from a bottle into the bucket (or nearby bowl) before placing an item on top of the bucket.',
#                 'support': [1774, 2698],
#                 'confidence': None,
#                 'node_id': 'd5ed0a20-7b4b-552c-8c16-c47f4e9d7330',
#                 'parent_id': '121e35d3-271c-581e-ba02-d7cf7f4852b7',
#                 'level': 5,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c63',
#                 'tags': [],
#                 'label': 'The clip begins with a close‑up of a man wearing a welding mask, gloves and casual work clothes holding a plasma‑cutting torch over a metal piece on a bench. The camera first focuses on the torch and the bright arc as it cuts and fuses the metal, then pulls back to reveal the gloved hands guiding the tool. Two freshly made welds are shown in close‑up, followed by a wider view of the completed workpiece. The final frame zooms in on an emblem stamped on the metal that reads “The Fast Forward” in yellow lettering against a dark‑gray background.',
#                 'support': [223, 359],
#                 'confidence': None,
#                 'node_id': 'cdbc68a8-31cf-5d89-888e-807303eeb946',
#                 'parent_id': 'cc82ec91-1e2e-5c3a-8c6e-6bd19e7417d1',
#                 'level': 6,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c68',
#                 'tags': [],
#                 'label': 'In a brightly illuminated kitchen with white cupboards, a black refrigerator displaying a calendar, a microwave, a black oven on the right, and a brown marble‑like countertop, a man whose face is blurred stands facing the camera. He wears a black T‑shirt and a backwards black baseball cap. While speaking, he makes a quick motion with his left hand and then points to his right with the same hand.',
#                 'support': [518, 675],
#                 'confidence': None,
#                 'node_id': '2cf0bf54-2296-5555-95f9-50daa2fa0a44',
#                 'parent_id': '99fbd398-d4ae-5ede-9152-733623ad3248',
#                 'level': 6,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c6d',
#                 'tags': [],
#                 'label': 'The man stands in the centre of a kitchen wearing a black T‑shirt, a black baseball cap with a white rim, glasses, and a beard and mustache. Behind him are white cabinets, a granite countertop, a refrigerator, a microwave, an electric range and a dark red wall. He looks directly at the camera and speaks. While talking he raises his right hand, extending the thumb and index finger toward the camera, then moves his left arm back and forth and at one point forms an “I” shape with two fingers. Apart from slight head movement he remains mostly stationary.',
#                 'support': [675, 963],
#                 'confidence': None,
#                 'node_id': '1a0cb318-7d03-529b-ace0-ff459efdcdf4',
#                 'parent_id': '99fbd398-d4ae-5ede-9152-733623ad3248',
#                 'level': 6,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c72',
#                 'tags': [],
#                 'label': 'Standing in a kitchen with white cabinets, a refrigerator, a window and a door with floral curtains, a man wearing a black T‑shirt, a black baseball cap and a beard holds a pair of black Dickies pants by the waist. He first presents the front side, rotating the pants left and right so the fabric and the "874 ORIGINAL FIT" label are visible. He then steps back a few steps, flips the pants over, raises the waistband toward the camera and checks the rear tag and bottom of the legs.',
#                 'support': [1014, 1295],
#                 'confidence': None,
#                 'node_id': '5337e319-ce45-530f-a38a-67a543390bc6',
#                 'parent_id': '47076e10-447a-5153-9b71-e21fd10f9a5a',
#                 'level': 6,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c77',
#                 'tags': [],
#                 'label': 'Standing in a brightly lit kitchen, a man wearing a black T‑shirt, black baseball cap, glasses, a neatly trimmed beard and mustache holds a grey denim jean in his right hand and then lifts a pair of black pants, examining them for the camera. He then picks up a black bag with a small white label, pulls the flap open and fully expands the bag, showing the bag’s interior and how it fits around a shoe, while the kitchen background with white cabinets and marble countertops remains unchanged.',
#                 'support': [1295, 1638],
#                 'confidence': None,
#                 'node_id': '2cb2aa0f-bfd0-5409-b61b-cc6cd3035d60',
#                 'parent_id': 'f396e88e-7f67-5a28-b652-de3645807d9a',
#                 'level': 6,
#                 'tier': 'mid',
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c7c',
#                 'tags': [],
# ...
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400bff',
#                 'tags': [],
#                 'label': 'front  you  put  them  on  right  now  you  feel',
#                 'support': [1251, 1313],
#                 'confidence': None,
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c00',
#                 'tags': [],
#                 'label': 'like  you  should  be  going  to  church  or',
#                 'support': [1313, 1349],
#                 'confidence': None,
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c01',
#                 'tags': [],
#                 'label': 'something  like  super  stiff  like  a  dress',
#                 'support': [1349, 1413],
#                 'confidence': None,
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c02',
#                 'tags': [],
#                 'label': 'pant  so  what  I  like  to  do  is  brine',
#                 'support': [1413, 1560],
#                 'confidence': None,
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c03',
#                 'tags': [],
#                 'label': 'them  yep  if  you  like  to  cook  you  know',
#                 'support': [1560, 1637],
#                 'confidence': None,
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c04',
#                 'tags': [],
#                 'label': 'what  a  Brian  is  and  yes  you  do  it  the',
#                 'support': [1637, 1715],
#                 'confidence': None,
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c05',
#                 'tags': [],
#                 'label': 'same  exact  way  so  I  to  start  off  with',
#                 'support': [1715, 1802],
#                 'confidence': None,
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c06',
#                 'tags': [],
#                 'label': 'the  5  gallon',
#                 'support': [1802, 1863],
#                 'confidence': None,
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c07',
#                 'tags': [],
#                 'label': 'bucket  and  uh  fill  it  with  hot',
#                 'support': [1863, 2326],
#                 'confidence': None,
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c08',
#                 'tags': [],
#                 'label': 'water  all  right  you  want  to  fill  it  with',
#                 'support': [2326, 2433],
#                 'confidence': None,
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c09',
#                 'tags': [],
#                 'label': 'hot  water  and  the  reason  why  is  cuz',
#                 'support': [2433, 2522],
#                 'confidence': None,
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c0a',
#                 'tags': [],
#                 'label': "you're  going  to  put  salt  in  it  okay  this",
#                 'support': [2522, 2611],
#                 'confidence': None,
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c0b',
#                 'tags': [],
#                 'label': 'is  eye  dye  salt  just  cheap  version  of',
#                 'support': [2611, 2695],
#                 'confidence': None,
#             }>,
#             <TemporalDetection: {
#                 'id': '698d1a685a33217ed9400c0c',
#                 'tags': [],
#                 'label': 'under  a  buck  for  this  whole  thing  I  just',
#                 'support': [2695, 2698],
#                 'confidence': None,
#             }>,
#         ],
#     }>,
#     'qwen_embeddings': array([ 0.04370117, -0.00830078,  0.01757812, ..., -0.01135254,
#             0.02966309, -0.0324707 ], dtype=float32),
#     'predicted_class': <Classification: {
#         'id': '699cd54102b277e1d2808ef5',
#         'tags': [],
#         'label': 'Home Improvement and DIY',
#         'confidence': 0.0959148034453392,
#         'logits': None,
#     }>,
#     'molmo_embeddings': array([ 0.00152245, -0.00336027,  0.00258669, ...,  0.00192303,
#             0.00933988, -0.0120441 ], dtype=float32),
#     'text_embeddings': array([ 0.02624512, -0.00253296, -0.02380371, ..., -0.01519775,
#             0.03063965, -0.01647949], dtype=float32),
#     'qwen_uniqueness': 0.7595215999042797,
#     'qwen_rep': 0.8009834885597229,
#     'qwen_desc_summary': 'The video begins with a montage of various scenes showcasing automotive craftsmanship and welding work. The first scene features a vintage-style hot rod with a shiny metallic body and exposed engine components, parked inside a well-equipped garage. The camera pans around the vehicle, highlighting its classic design and custom modifications. The next scene transitions to a man welding metal parts in a workshop, with sparks flying as he works on a metal frame. The focus is on the precision and skill involved in the welding process, emphasizing the craftsmanship required in automotive restoration.\n\nThe video then cuts to a close-up of a sign that reads "TheFabFunk.com," suggesting a connection to a website or brand related to automotive customization or fabrication. This is followed by a scene of a man standing in a kitchen, wearing a black t-shirt and a cap. He appears to be addressing the camera, likely introducing or explaining something related to the content of the video. The kitchen is well-lit, with white cabinets and a granite countertop, creating a casual and homey atmosphere.\n\nThe man then picks up a pair of work gloves, showing them to the camera. He discusses the gloves, possibly explaining their features or why he chose them for a particular task. He then proceeds to put on the gloves, indicating that he is preparing for some kind of hands-on activity. The scene transitions to the man standing at the kitchen sink, where he begins to wash the gloves. He fills the sink with water and uses a bottle of soap, carefully cleaning the gloves to ensure they are thoroughly washed and ready for use.\n\nThroughout the video, the man\'s actions are deliberate and focused, suggesting that he is preparing for a task that requires precision and care. The overall tone of the video is informative and engaging, with a mix of technical and casual elements that appeal to viewers interested in automotive work and DIY projects. The video effectively combines scenes of automotive craftsmanship with everyday activities, creating a cohesive narrative that highlights the man\'s skills and preparation for his upcoming task.',
#     'qwen_events_events': <TemporalDetections: {
#         'detections': [
#             <TemporalDetection: {
#                 'id': '699d6dc602b277e1d2809378',
#                 'tags': [],
#                 'label': 'A man is shown welding in a garage, and then a logo appears on the screen.',
#                 'support': [1, 346],
#                 'confidence': None,
#             }>,
#             <TemporalDetection: {
#                 'id': '699d6dc602b277e1d2809379',
#                 'tags': [],
#                 'label': 'A man with a beard is talking to the camera in his kitchen.',
#                 'support': [361, 990],
#                 'confidence': None,
#             }>,
#             <TemporalDetection: {
#                 'id': '699d6dc602b277e1d280937a',
#                 'tags': [],
#                 'label': 'The man shows off a pair of jeans he bought at a store.',
#                 'support': [1020, 1349],
#                 'confidence': None,
#             }>,
#             <TemporalDetection: {
#                 'id': '699d6dc602b277e1d280937b',
#                 'tags': [],
#                 'label': 'The man shows off a pair of gloves he bought at a store.',
#                 'support': [1379, 1709],
#                 'confidence': None,
#             }>,
#             <TemporalDetection: {
#                 'id': '699d6dc602b277e1d280937c',
#                 'tags': [],
#                 'label': 'The man is shown washing his jeans in a sink with a bucket of water and soap, and then he shows off a bag of detergent.',
#                 'support': [1739, 2667],
#                 'confidence': None,
#             }>,
#         ],
#     }>,
#     'qwen_comp_summary': 'The video showcases a man in a kitchen demonstrating how to wash and prepare work gloves, while also briefly showing scenes of car welding and fabrication in a garage. The man explains the process of cleaning the gloves, using a bucket, water, and detergent, and then rinsing them thoroughly. The video also includes glimpses of a custom car being worked on, with welding activities and tools visible in the background.',
#     'qwen_comp_objects': <TemporalDetections: {
#         'detections': [
#             <TemporalDetection: {
#                 'id': '699db04f02b277e1d280acf5',
#                 'tags': [],
#                 'label': 'Man',
#                 'support': [1, 1],
#                 'confidence': None,
#             }>,
#             <TemporalDetection: {
#                 'id': '699db04f02b277e1d280acf6',
#                 'tags': [],
#                 'label': 'Work gloves',
#                 'support': [1, 1],
#                 'confidence': None,
#             }>,
#             <TemporalDetection: {
#                 'id': '699db04f02b277e1d280acf7',
#                 'tags': [],
#                 'label': 'Red bucket',
#                 'support': [1, 1],
#                 'confidence': None,
#             }>,
#             <TemporalDetection: {
#                 'id': '699db04f02b277e1d280acf8',
#                 'tags': [],
#                 'label': 'Detergent bottle',
#                 'support': [1, 1],
#                 'confidence': None,
#             }>,
#             <TemporalDetection: {
#                 'id': '699db04f02b277e1d280acf9',
#                 'tags': [],
#                 'label': 'Welding machine',
#                 'support': [1, 1],
#                 'confidence': None,
#             }>,
#             <TemporalDetection: {
#                 'id': '699db04f02b277e1d280acfa',
#                 'tags': [],
#                 'label': 'Custom car',
#                 'support': [1, 1],
#                 'confidence': None,
#             }>,
#             <TemporalDetection: {
#                 'id': '699db04f02b277e1d280acfb',
#                 'tags': [],
#                 'label': 'Welding torch',
#                 'support': [1, 1],
#                 'confidence': None,
#             }>,
#         ],
#     }>,
#     'qwen_comp_events': <TemporalDetections: {
#         'detections': [
#             <TemporalDetection: {
#                 'id': '699db04f02b277e1d280acfc',
#                 'tags': [],
#                 'label': 'The man stands in the kitchen and introduces the topic, holding up a pair of work gloves.',
#                 'support': [1, 1],
#                 'confidence': None,
#             }>,
#             <TemporalDetection: {
#                 'id': '699db04f02b277e1d280acfd',
#                 'tags': [],
#                 'label': 'The man demonstrates how to wash the work gloves by filling a bucket with water and detergent, then rinsing them.',
#                 'support': [1, 1],
#                 'confidence': None,
#             }>,
#             <TemporalDetection: {
#                 'id': '699db04f02b277e1d280acfe',
#                 'tags': [],
#                 'label': 'The man continues washing the gloves, showing the process step by step, including pouring detergent and rinsing.',
#                 'support': [1, 1],
#                 'confidence': None,
#             }>,
#         ],
#     }>,
#     'qwen_comp_text_content': <TemporalDetections: {
#         'detections': [
#             <TemporalDetection: {
#                 'id': '699db04f02b277e1d280acff',
#                 'tags': [],
#                 'label': 'Thefabfunk.com',
#                 'support': [1, 1],
#                 'confidence': None,
#             }>,
#             <TemporalDetection: {
#                 'id': '699db04f02b277e1d280ad00',
#                 'tags': [],
#                 'label': '874',
#                 'support': [1, 1],
#                 'confidence': None,
#             }>,
#             <TemporalDetection: {
#                 'id': '699db04f02b277e1d280ad01',
#                 'tags': [],
#                 'label': 'Absorbent fit',
#                 'support': [1, 1],
#                 'confidence': None,
#             }>,
#         ],
#     }>,
#     'qwen_comp_scene_info_setting': <Classification: {
#         'id': '699db04f02b277e1d280ad02',
#         'tags': [],
#         'label': 'Kitchen',
#         'confidence': None,
#         'logits': None,
#     }>,
#     'qwen_comp_scene_info_time_of_day': <Classification: {
#         'id': '699db04f02b277e1d280ad03',
#         'tags': [],
#         'label': 'Daytime',
#         'confidence': None,
#         'logits': None,
#     }>,
#     'qwen_comp_scene_info_location_type': <Classification: {
#         'id': '699db04f02b277e1d280ad04',
#         'tags': [],
#         'label': 'Indoor',
#         'confidence': None,
#         'logits': None,
#     }>,
#     'qwen_comp_activities_primary_activity': <Classification: {
#         'id': '699db04f02b277e1d280ad05',
#         'tags': [],
#         'label': 'Washing work gloves',
#         'confidence': None,
#         'logits': None,
#     }>,
#     'qwen_comp_activities_secondary_activities': <Classifications: {
#         'classifications': [
#             <Classification: {
#                 'id': '699db04f02b277e1d280ad06',
#                 'tags': [],
#                 'label': 'Welding',
#                 'confidence': None,
#                 'logits': None,
#             }>,
#             <Classification: {
#                 'id': '699db04f02b277e1d280ad07',
#                 'tags': [],
#                 'label': 'Fabricating custom car',
#                 'confidence': None,
#                 'logits': None,
#             }>,
#         ],
#         'logits': None,
#     }>,
#     'qwen_custom_result': '{\n    "type": "object",\n    "properties": {\n        "summary": {\n            "type": "object",\n            "properties": {\n                "brief": "A man demonstrates how to wash and prepare work gloves for use.",\n                "detailed": "A man in a kitchen is shown preparing work gloves for use by washing them in a sink, demonstrating the process of cleaning and preparing them for use."\n            }\n        },\n        "action": {\n            "type": "object",\n            "properties": {\n                "brief": "Washing work gloves",\n                "detailed": "The man fills a sink with water, adds detergent, and washes the work gloves thoroughly under running water.",\n                "actor": "The man"\n            }\n        }\n    },\n    "required": ["summary", "action"]\n}',
#     'molmo_custom_description': '{\n    "type": "object",\n    "properties": {\n        "summary": {\n            "type": "object",\n            "properties": {\n                "brief": "A man demonstrates car restoration and maintenance techniques in a workshop and kitchen setting.",\n                "detailed": "The video showcases various aspects of car restoration, including welding and metalwork, followed by a transition to a kitchen where the man discusses and demonstrates different maintenance tasks and products."\n            }\n        },\n        "action": {\n            "type": "object",\n            "properties": {\n                "brief": "Demonstrating and explaining car restoration and maintenance techniques.",\n                "detailed": "The man holds up and displays various items, including a pair of jeans and a red bucket, while pouring liquid from a can into the bucket and explaining their use in car maintenance.",\n                "actor": "A man wearing a black baseball cap and black t-shirt"\n            }\n        }\n    },\n    "required": ["summary", "action"]\n}',
#     'frames': <Frames: 0>,
# }>

# %% [markdown]
# Once you have your dataset, you can [launch the app](https://docs.voxel51.com/user_guide/app.html#using-the-fiftyone-app) and see what's in it.

# %%
# Open the FiftyOne App and explore the dataset
session = fo.launch_app(dataset, auto=False)
session.url
# Out:
# Session launched. Run `session.show()` to open the App in a cell output.
# INFO:fiftyone.core.session.session:Session launched. Run `session.show()` to open the App in a cell output.
# Welcome to
#
# ███████╗██╗███████╗████████╗██╗   ██╗ ██████╗ ███╗   ██╗███████╗
# ██╔════╝██║██╔════╝╚══██╔══╝╚██╗ ██╔╝██╔═══██╗████╗  ██║██╔════╝
# █████╗  ██║█████╗     ██║    ╚████╔╝ ██║   ██║██╔██╗ ██║█████╗
# ██╔══╝  ██║██╔══╝     ██║     ╚██╔╝  ██║   ██║██║╚██╗██║██╔══╝
# ██║     ██║██║        ██║      ██║   ╚██████╔╝██║ ╚████║███████╗
# ╚═╝     ╚═╝╚═╝        ╚═╝      ╚═╝    ╚═════╝ ╚═╝  ╚═══╝╚══════╝ v1.14.0
#
# If you're finding FiftyOne helpful, here's how you can get involved:
#
# |
# |  ⭐⭐⭐ Give the project a star on GitHub ⭐⭐⭐
# |  https://github.com/voxel51/fiftyone
# |
# |  🚀🚀🚀 Join the FiftyOne Discord community 🚀🚀🚀
# |  https://community.voxel51.com/
# |
# INFO:fiftyone.core.session.session:
# Welcome to
#
# ███████╗██╗███████╗████████╗██╗   ██╗ ██████╗ ███╗   ██╗███████╗
# ██╔════╝██║██╔════╝╚══██╔══╝╚██╗ ██╔╝██╔═══██╗████╗  ██║██╔════╝
# █████╗  ██║█████╗     ██║    ╚████╔╝ ██║   ██║██╔██╗ ██║█████╗
# ██╔══╝  ██║██╔══╝     ██║     ╚██╔╝  ██║   ██║██║╚██╗██║██╔══╝
# ██║     ██║██║        ██║      ██║   ╚██████╔╝██║ ╚████║███████╗
# ╚═╝     ╚═╝╚═╝        ╚═╝      ╚═╝    ╚═════╝ ╚═╝  ╚═══╝╚══════╝ v1.14.0
#
# If you're finding FiftyOne helpful, here's how you can get involved:
#
# |
# |  ⭐⭐⭐ Give the project a star on GitHub ⭐⭐⭐
# |  https://github.com/voxel51/fiftyone
# |
# |  🚀🚀🚀 Join the FiftyOne Discord community 🚀🚀🚀
# |  https://community.voxel51.com/
# |
# 'https://5151-gpu-t4-s-kkb-usw4a1-3lv4zo4y7hca2-a.us-west4-1.prod.colab.dev?polling=true'

# %% [markdown]
# **What to look at in the App:**
#
# 1. Play a few videos and toggle on `gpt_action_brief` — watch how the temporal segments track the actions you see on screen
# 2. Click on a sample with high `tree_depth` (try sorting by it) — notice how the annotations at level 0 are broad overviews, while leaf-level annotations are very fine-grained moments
# 3. Look at the `transcript` field — this is the raw ASR text, much noisier than the GPT-refined annotations
# 4. Check a few `gpt_summary_detailed` labels — these are the longest annotations (~540 words average)
#
# > **Key question to hold in mind:** Every one of these labels came from an automated pipeline. They look authoritative. But should we trust them?

# %% [markdown]
# ---
# ## Section 2: Three Lenses on the Same Data
#
# Before interrogating the existing annotations, let's build our own understanding of the dataset — using nothing but the raw videos and transcripts.
#
# We'll create three separate embedding spaces:
#
# 1. **Visual ([Qwen3-VL-Embedding](https://docs.voxel51.com/plugins/plugins_ecosystem/qwen3vl_embeddings.html)):** What the videos look like — and crucially, this lives in a shared text-video space, so we can search with natural language
#
# 2. **Visual-Grounding ([Molmo2](https://docs.voxel51.com/plugins/plugins_ecosystem/molmo2.html)):** A different visual understanding — video-to-video similarity only, but from a model trained on grounding and spatial reasoning
#
# 3. **Language (Transcript):** What people are *saying* in these videos, embedded with a text model
#
# The insight from comparing these three spaces is the foundation of everything that follows: **what you embed determines what you find**.

# %% [markdown]
# ### Lens 1: Visual Content (Qwen3-VL-Embedding)
#
# [Qwen3-VL-Embedding](https://huggingface.co/Qwen/Qwen3-VL-Embedding-2B) maps video and text into a shared vector space. This means we can embed a natural language query and find videos that match without touching any of the existing labels. It's semantic search, not keyword search.

# %%
# Load the 2B embedding model — good balance of quality and speed
import fiftyone.zoo as foz

foz.register_zoo_model_source(
    "https://github.com/harpreetsahota204/qwen3vl_embeddings",
    overwrite=True
)

qwen_emb_model = foz.load_zoo_model(
    "Qwen/Qwen3-VL-Embedding-2B",
)

qwen_emb_model.max_length=32768

# Compute embeddings — stores a vector on each sample
dataset.compute_embeddings(
    qwen_emb_model,
    embeddings_field="qwen_embeddings",
    batch_size=64,
    num_workers=8,
    skip_failures=False,
)

# %% [markdown]
# ### What you can do after computing embeddings in FiftyOne
#
# Once you've computed embeddings, you unlock powerful workflows:
#
# #### Visualize your embeddings in the App
#
# [Use `compute_visualization()`](https://docs.voxel51.com/brain.html#visualizing-embeddings) to reduce embeddings with UMAP, t‑SNE, or PCA and explore them in the Embeddings panel to:
# - See clusters and data structure
# - Understand how classes group together
# - Lasso regions to create views and filter subsets

# %%
import fiftyone.brain as fob

# Project into 2D with UMAP for visualization
fob.compute_visualization(
    dataset,
    method="umap",
    brain_key="qwen_viz",
    embeddings="qwen_embeddings",
    num_dims=2,
)

# %% [markdown]
# ####  Search by visual similarity
#
# [Build a similarity index](https://docs.voxel51.com/brain.html#similarity) with `compute_similarity()` to:
# - Find similar images (image‑to‑image search)
# - Detect duplicates or unique samples
# - Enable visual search in the App or via Python

# %%
# Build a similarity index — this is what powers text-to-video search
fob.compute_similarity(
    dataset,
    model="Qwen/Qwen3-VL-Embedding-2B",
    brain_key="qwen_sim",
    embeddings="qwen_embeddings",
)

# %% [markdown]
# You can also use this model for zero-shot classification. Let's add a Field to the Dataset:

# %%
classes = [
    "Cooking and Food",
    "Home Improvement and DIY",
    "Health and Beauty",
    "Hobbies and Crafts",
    "Sports and Fitness",
    "Gardening",
    "Technology and Electronics",
    "Fashion and Style",
    "Arts and Music",
    "Automotive",
    "Pets and Animals",
    "Education and Learning"
]

# Configure model for classification
qwen_emb_model.classes = classes
qwen_emb_model.text_prompt = "A video about "

# Apply zero-shot classification
dataset.apply_model(
    qwen_emb_model,
    label_field="predicted_class"
    )

# %% [markdown]
# ### Lens 2: Visual-Grounding (Molmo2)
#
# Molmo2 is a different kind of vision-language model — it's trained heavily on grounding tasks: pointing to objects, tracking them through time, and counting. Its internal representations will weight spatial and motion features differently than Qwen3-VL-Embedding.
#
# We can't do text-to-video search with Molmo2 embeddings, but we can still visualize the embedding space and do video-to-video similarity.
#
# The question is: **do two different visual models agree on which videos are similar?**

# %%
import fiftyone.zoo as foz

foz.register_zoo_model_source(
    "https://github.com/harpreetsahota204/molmo2",
    overwrite=True
)

molmo_model = foz.load_zoo_model("allenai/Molmo2-4B")

molmo_model.pooling_strategy = "mean"

dataset.compute_embeddings(
    molmo_model,
    embeddings_field="molmo_embeddings",
    batch_size=64,
    num_workers=4,
    skip_failures=False,
)

# %%
import fiftyone.brain as fob

fob.compute_visualization(
    dataset,
    method="umap",
    brain_key="molmo_viz",
    embeddings="molmo_embeddings",
    num_dims=2,
)

fob.compute_similarity(
    dataset,
    brain_key="molmo_sim",
    embeddings="molmo_embeddings",
)

# %% [markdown]
# ### Lens 3: Language (Transcript Embeddings)
#
# Both visual embeddings above represent what you *see* in the videos. Now let's embed what you *hear* — the ASR transcript text.
#
# Instructional videos vary enormously in how much they narrate. Some presenters talk through every step; others work in silence. The transcript embedding space captures this variation in a way neither visual model can.
#
# Fo this we can make use of [`jina-embeddings-v5-text-small-clustering`](https://huggingface.co/jinaai/jina-embeddings-v5-text-small-clustering).
#
# This model is not integrated as a remote source zoo model, but we can make use of it by extracting the transcripts from the videos using the `values` method of the [Dataset](https://docs.voxel51.com/user_guide/basics.html#datasets) to get all the values of the [Field](https://docs.voxel51.com/user_guide/basics.html#fields) into a Python list.
#
# With the values in a list we can use the model natively and then add the results back as a Field to the Dataset using [the `set_values`](https://docs.voxel51.com/api/fiftyone.core.collections.html#fiftyone.core.collections.SampleCollection.set_values) method.

# %%
import os
import torch
from sentence_transformers import SentenceTransformer

#set an environment variable so tokenizers doesn't yell at us,
# note this related to the `transformers` and `tokenizers` libraries and not a FiftyOne specific environment variable
os.environ["TOKENIZERS_PARALLELISM"] = "false"

text_emb_model = SentenceTransformer(
    "jinaai/jina-embeddings-v5-text-small-clustering",
    model_kwargs={"dtype": torch.bfloat16}, #recommended for GPUs
    config_kwargs={"attn_implementation": "flash_attention_2", "device":"cuda"}, #flash attn optional, but recommended
    tokenizer_kwargs={"extra_special_tokens": {}}, # This line fixes the AttributeError: 'list' object has no attribute 'keys'
)

transcripts = dataset.values("transcript")

# Encode texts
text_embeddings = text_emb_model.encode(transcripts)

dataset.set_values("text_embeddings", text_embeddings)

# %% [markdown]
# We can compute visualizations of the embeddings just like before:

# %%
import fiftyone.brain as fob

fob.compute_visualization(
    dataset,
    method="umap",
    brain_key="transcript_viz",
    embeddings="text_embeddings",
    num_dims=2,
)

fob.compute_similarity(
    dataset,
    brain_key="text_sim",
    embeddings="text_embeddings",
)

# %% [markdown]
# We can also generate some Classifications for the Samples based on the title and description:

# %%
import os
import torch
from sentence_transformers import SentenceTransformer

text_cls_model = SentenceTransformer(
    "jinaai/jina-embeddings-v5-text-small-classification",
    model_kwargs={"dtype": torch.bfloat16}, #recommended for GPUs
    config_kwargs={"attn_implementation": "flash_attention_2", "device":"cuda"}, #flash attn optional, but recommended
    tokenizer_kwargs={"extra_special_tokens": {}}, # This line fixes the AttributeError: 'list' object has no attribute 'keys'
    trust_remote_code=True
)

classes = [
    "Cooking and Food",
    "Home Improvement and DIY",
    "Health and Beauty",
    "Hobbies and Crafts",
    "Sports and Fitness",
    "Gardening",
    "Technology and Electronics",
    "Fashion and Style",
    "Arts and Music",
    "Automotive",
    "Pets and Animals",
    "Education and Learning"
]

# grab the titles for the videos
_titles = dataset.values("title")

# grab the descriptions for the videos
_desc = dataset.values("description")

# combine them into one string
title_desc = [t + " " + d for t, d in zip(_titles, _desc)]

# Encode texts
title_embeddings = text_cls_model.encode(title_desc, prompt_name="document")

class_embeddings = text_cls_model.encode(classes, prompt = "The title of a YouTube video about ")

# compute cosine similarity
similarity = text_cls_model.similarity(title_embeddings, class_embeddings)

# %% [markdown]
# Now let's parse this back `similarity`, which is a [num_samples × num_classes] tensor of cosine similarity scores.
#
# Each row is one video, each column is one class, and each value measures how geometrically close the text embedding is to that class label's embedding.
#
# `argmax` gives us the column index (class) with the highest score per row (sample), so we can slice into our classes list, and `max` gives us the score itself, which we store as confidence.
#
# This is zero-shot classification: no fine-tuning, no labeled training data.

# %%
predicted_indices = similarity.argmax(dim=1).tolist()

confidence_scores = similarity.max(dim=1).values.tolist()

predicted_labels = [
    fo.Classification(
        label=classes[idx],
        confidence=conf,
    )
    for i, (idx, conf) in enumerate(zip(predicted_indices, confidence_scores))
]

dataset.set_values("jina_predicted_class", predicted_labels)

dataset.save()

# %% [markdown]
# Now, we don't have ground truth classifications for the classification of the videos.
#
# So, let's assume that the classifications we got when using Qwen3-VL-Embeddings are the ground truth.
#
# We can evaluate how well the classifications using the Jina text embedding model is like so:

# %%
classification_results = dataset.evaluate_classifications(
    "jina_predicted_class",
    gt_field="predicted_class",
    eval_key="simple_cls_eval",
)

# %% [markdown]
# I'll show you a more interactive evaluation panel when we return to the app, but for now you can view the results at a high-level like so:

# %%
classification_results.print_report()

# %% [markdown]
# ### Using Embeddings to Compute Uniqueness and Representativeness Values
#
# In FiftyOne, both **uniqueness** and **representativeness** are scalar scores computed from embeddings that describe how a sample relates to the rest of the dataset.
#
# #### Uniqueness
#
# - [Measures **how different (dissimilar)**](https://docs.voxel51.com/brain.html#image-uniqueness) a sample is from its neighbors in embedding space.
#
# - Implemented by looking at each sample’s nearest neighbors, weighting their distances (e.g. 60%-30%-10%), and normalizing to a score in **\[0, 1\]**. Higher scores mean the sample is more “isolated” or distinct; lower scores mean it has many close neighbors.
#
# - The most unique sample in a collection has a uniqueness value of **1**.
#
# - Useful for:
#   - Finding **outliers / edge cases / bad actors**
#   - Detecting **near-duplicates** (by looking at *low* uniqueness)
#   - Selecting **diverse samples** for annotation when budget is limited

# %%
import fiftyone.brain as fob

fob.compute_uniqueness(
    dataset,
    uniqueness_field = "qwen_uniqueness",
    embeddings = "qwen_embeddings",
    batch_size=64,
    num_workers=4
)

# %% [markdown]
# ## Representativeness
#
# - [Measures **how typical** or **central** ](https://docs.voxel51.com/brain.html#image-representativeness) a sample is relative to the rest of the dataset in embedding space.
#
# - Also normalized to **\[0, 1\]**, with the most representative samples having value **1**.
#
# - High representativeness ≈ sample lies in a dense, central region of the data; it’s similar to many other samples.
#
# - Useful for:
#   - **Active learning**: picking representative samples to cover common patterns
#   - **Dataset balancing**: finding under/overrepresented regions
#   - **Efficient annotation**: prioritizing samples that “stand in” for many others
#
# In short:
#
# - **Uniqueness** → “How unusual is this sample?”
# - **Representativeness** → “How well does this sample represent many others?”

# %%
import fiftyone.brain as fob

fob.compute_representativeness(
    dataset,
    representativeness_field = "qwen_rep",
    embeddings = "qwen_embeddings",
    batch_size=64,
    num_workers=4
)

# %% [markdown]
# ### The Cross-Lens Moment
#
# Try to **find a tight visual cluster in the Qwen UMAP, then look at where those same videos land in the transcript UMAP.**
#
# You may find that videos which cluster tightly by visual content are often spread out in transcript space. Cooking videos that all look similar — same kitchen setup, same hands-on-food visual — may use completely different spoken language: detailed step-by-step narration, casual conversational chat, or total silence.
#
# This is not a failure of any embedding model, but a property of the data: **visual similarity and linguistic similarity are measuring different things.** Your choice of embedding determines what questions you can ask.
#
# - Qwen visual embeddings to find *visually similar content* or do text-to-video semantic search
#
# - Molmo2 embeddings to find videos with similar *physical actions and spatial structure*
#
# - Transcript embeddings to find videos that *talk about similar topics*

# %%
# Pick a video and find its nearest neighbors in each embedding space —
# a concrete way to see how the three spaces differ
from fiftyone import ViewField as F

sample = dataset.first()

root_view = dataset.filter_labels("gpt_summary_brief", F("tier") == "root")

print(f"Reference video: {sample.title}")
ref_root = root_view[sample.id].gpt_summary_brief.detections[0].label
print(f"Root summary: {ref_root}\n")

for brain_key, label in [
    ("qwen_sim", "Based on QwenVL Embeddings"),
    ("molmo_sim", "Based on Molmo Embeddings"),
    ("text_sim", "Based on Text Embeddings")
    ]:
    neighbors = root_view.sort_by_similarity(sample.id, brain_key=brain_key, k=4)
    print(f"Nearest neighbors ({label}):")
    for n in neighbors.skip(1).take(3):
        print(f"  → {n.gpt_summary_brief.detections[0].label}")
    print()

# %% [markdown]
# **What to look at:**
#
# - In the Embeddings panel, hover over clusters. Click points to see which videos land near each other. Try coloring by `tree_depth` or `title` to see if the visual clusters map onto any metadata patterns.
#
#
# - Compare the Molmo2 UMAP with the Qwen UMAP. Are the clusters in the same positions? Similar shape, different boundaries — this is two models with different visual priors producing different embedding spaces. Neither is "correct" — they're measuring different aspects of the same content.

# %% [markdown]
# ---
# ## Section 3: The Second Opinion
#
# We've built three independent maps of the dataset. Now let's do what the original pipeline did — but with a completely different model.
#
# The Action100M annotations were produced by GPT-OSS-120B processing outputs from PerceptionLM-3B and Llama-3.2-Vision-11B.
#
# We're going to run **Qwen3-VL-8B** on the same videos, completely independently, and ask:
#
# - How would *you* describe this video?
#
# - What events do *you* see, and when?
#
# We're not trying to beat the pipeline. We're trying to get a second opinion. Where the two agree, we gain confidence in the original annotation. Where they diverge, we've found something worth looking at.

# %%
import fiftyone.zoo as foz

foz.register_zoo_model_source(
    "https://github.com/harpreetsahota204/qwen3vl_video",
    overwrite=True
)

qwen_video_model = foz.load_zoo_model(
    "Qwen/Qwen3-VL-8B-Instruct",
)

# Generate a full-video description for every sample.
# This produces a string field: qwen_desc_summary
qwen_video_model.operation = "description"

# %%
print(qwen_video_model.prompt)

# %% [markdown]
# #### Generate detailed video description

# %%
dataset.apply_model(
    qwen_video_model,
    label_field="qwen_desc",
    skip_failures=True,
)

# %% [markdown]
# #### Comprehensive analysis
#
# Analyzes video for all aspects: description, events, objects, scene info, activities.
#
# Output fields:
#
# - `analysis_summary` - Video description (string)
# - `analysis_events` - Temporal events (fo.TemporalDetections)
# - `analysis_objects` - Object appearances (fo.TemporalDetections)
# - `analysis_scene_info_*` - Scene classifications
# - `analysis_activities_*` - Activity classifications
# - `sample.frames[N].objects` - Frame-level object detections
# - `sample.frames[N].text_content` - Frame-level OCR

# %%
qwen_video_model.operation = "comprehensive"

print(qwen_video_model.prompt)

# %%
qwen_video_model.operation = "comprehensive"

dataset.apply_model(
    qwen_video_model,
    label_field="qwen_comp",
    skip_failures=True,
)

# %% [markdown]
# You'll notice the descriptions often describe the same video in quite different language — different vocabulary, different sentence structure, different level of detail. Sometimes one catches a detail the other misses.
#
# The question is: **how do we move from "these look different" to a number we can sort and filter by?**

# %% [markdown]
# #### Using a prompt from the paper
#
# In the paper they describe some prompts they use. We can prompt Qwen3-VL the same way and see what we end up with:

# %%
PROMPT = """Identify the main actor and the physical action performed in the current segment. Provide both a brief
description that represents the overall action step, and a detailed description that contains sufficient
procedural detail. Use "N/A" (without further explaination) if there are no visible actors or physical
actions (e.g., static).

# Response Formats
## output
{
    "type": "object",
    "properties": {
        "summary": {
            "type": "object",
            "properties": {
                "brief": {
                    "type": "string",
                    "description": "Single sentence video caption."
                },
                "detailed": {
                    "type": "string",
                    "description": "Detailed, comprehensive description."
                }
            }
        },
        "action": {
            "type": "object",
            "properties": {
                "brief": {
                    "type": "string",
                    "description": "A single verb phrase (no -ing forms) brifly summarizing the overall action content."
                },
                "detailed": {
                    "type": "string",
                    "description": "A single imperitive sentence describing how the action is performed with more details."
                },
                "actor": {
                    "type": "string",
                    "description": "Single sentece or an imformative noun phrase describing who is performing the action."
                }
            }
        }
    },
    "required": ["summary", "action"]
}"""

# %%
# Generate a full-video description for every sample.
# This produces a string field: qwen_desc_summary

qwen_video_model.operation = "custom"

qwen_video_model.prompt = PROMPT

dataset.apply_model(
    qwen_video_model,
    label_field="qwen_custom",
    skip_failures=True,
)

# %% [markdown]
# We can also do the same with the Molmo2 model, let's use the 8B parameter model:

# %%
molmo_8b_model = foz.load_zoo_model("allenai/Molmo2-8B")

molmo_8b_model.operation = "describe"

molmo_8b_model.prompt = PROMPT

dataset.apply_model(
    molmo_8b_model,
    label_field="molmo_custom",
    skip_failures=True,
)

# %% [markdown]
# The model returned its output as a raw JSON string stored in `qwen_custom_result`.
#
# We parse the JSON once and promote each nested value to its own top-level string field.
#
# This makes every piece of structured output a first-class citizen in the dataset: filterable in the App, embeddable with a text model, and comparable against the existing GPT-generated fields (`gpt_summary_brief`, `gpt_action_actor`, etc.) that ship with the Action100M dataset.

# %%
import json

def extract(raw):
    try:
        parsed = json.loads(raw)
        props = parsed["properties"]
        s = props["summary"]["properties"]
        a = props["action"]["properties"]
        return s.get("brief"), s.get("detailed"), a.get("brief"), a.get("detailed"), a.get("actor")
    except:
        return None, None, None, None, None

SOURCES = [
    ("qwen_custom_result",       "qwen3vl"),
    ("molmo_custom_description", "molmo"),
]

for src_field, prefix in SOURCES:
    raws = dataset.values(src_field)
    results = [extract(r) for r in raws]

    dataset.set_values(f"{prefix}_summary_brief",    [r[0] for r in results])
    dataset.set_values(f"{prefix}_summary_detailed", [r[1] for r in results])
    dataset.set_values(f"{prefix}_action_brief",     [r[2] for r in results])
    dataset.set_values(f"{prefix}_action_detailed",  [r[3] for r in results])
    dataset.set_values(f"{prefix}_action_actor",     [r[4] for r in results])

dataset.save()

# %% [markdown]
# Each `gpt_summary_brief`, `gpt_summary_detailed`, etc. is a [`TemporalDetections` field](https://docs.voxel51.com/user_guide/using_datasets.html#temporal-detection) containing a list of detections across multiple tiers.
#
# We want to "hoist" just the root-tier detection's label string up to a flat sample-level field for easy filtering and comparison. To accomplish this we can [use a combination of `ViewField` and `Filtering`](https://docs.voxel51.com/user_guide/using_views.html#querying-samples).
#
# This is necessary for the next step in the workshop, where we will compare the Qwen3-VL outputs with the "ground truth".

# %%
from fiftyone import ViewField as F

# Fields to extract root labels from, and their new target field names
GPT_FIELDS = {
    "gpt_summary_brief":    "gpt_summary_root_brief",
    "gpt_summary_detailed": "gpt_summary_root_detailed",
    "gpt_action_brief":     "gpt_action_root_brief",
    "gpt_action_detailed":  "gpt_action_root_detailed",
    "gpt_action_actor":     "gpt_action_root_actor",
}

for src_field, dst_field in GPT_FIELDS.items():
    # Create a view that filters each sample's detections to root-tier only.
    # This does NOT mutate the dataset — it's a virtual filter.
    root_view = dataset.filter_labels(src_field, F("tier") == "root")

    # values() on a TemporalDetections field returns a list-of-lists:
    # one inner list per sample, containing the labels of surviving detections.
    # Since there is exactly one root per sample, each inner list has one element.
    nested = root_view.values(f"{src_field}.detections.label")

    # Flatten: take the first (only) label, or None if a sample had no root.
    flat = [labels[0] if labels else None for labels in nested]

    dataset.set_values(dst_field, flat)

dataset.save()

# %% [markdown]
# ---
# ## Section 4: Measuring Agreement
#
# Eyeballing agreement doesn't scale. We need metrics.
#
#
# ##### **Normalized Levenshtein Similarity**
#
# This metric measures how similar two text strings are on a scale from 0.0 to 1.0.
#
# **How it works:**
#
# 1. **Levenshtein Distance**: Counts the minimum number of single-character edits (insertions, deletions, substitutions) needed to transform one string into another.
#
# 2. **Normalization**: Converts the distance to a similarity score:
#
# $$
# \text{similarity} = 1.0 - \frac{\text{Levenshtein distance}}{\max(\text{len}(s_1), \text{len}(s_2))}
# $$
#
#
# 3. **Score**:
#    - **1.0** = perfect match
#    - **0.0** = completely different
#    - **0.0-1.0** = partial similarity
#
# **Example:**
#
# - **"hello"** vs **"hello"** → 1.0 (no edits)
# - **"hello"** vs **"helo"** → 0.8 (1 deletion / 5 chars)
# - **"hello"** vs **"world"** → 0.2 (4 substitutions / 5 chars)
#
# **Use Cases:**
#
# Evaluating OCR accuracy, transcription quality, text generation models, or any scenario requiring quantification of text similarity.

# %%
import fiftyone.operators as foo
import os

os.environ["FIFTYONE_ALLOW_LEGACY_ORCHESTRATORS"] = "true"

sim_op = foo.get_operator("@harpreetsahota/text-evaluation-metrics/compute_normalized_similarity")

# (pred_field, gt_field, output_field)
# lex_q_ = lexical similarity, Qwen vs GPT root
# lex_m_ = lexical similarity, Molmo vs GPT root
COMPARISON_PAIRS = [
    ("qwen3vl_summary_brief",    "gpt_summary_root_brief",    "lex_q_sum_brief"),
    ("qwen3vl_summary_detailed", "gpt_summary_root_detailed", "lex_q_sum_detailed"),
    ("qwen3vl_action_brief",     "gpt_action_root_brief",     "lex_q_act_brief"),
    ("qwen3vl_action_detailed",  "gpt_action_root_detailed",  "lex_q_act_detailed"),
    ("qwen3vl_action_actor",     "gpt_action_root_actor",     "lex_q_actor"),
    ("molmo_summary_brief",      "gpt_summary_root_brief",    "lex_m_sum_brief"),
    ("molmo_summary_detailed",   "gpt_summary_root_detailed", "lex_m_sum_detailed"),
    ("molmo_action_brief",       "gpt_action_root_brief",     "lex_m_act_brief"),
    ("molmo_action_detailed",    "gpt_action_root_detailed",  "lex_m_act_detailed"),
    ("molmo_action_actor",       "gpt_action_root_actor",     "lex_m_actor"),
]

for pred_field, gt_field, output_field in COMPARISON_PAIRS:
    sim_op(
        dataset,
        pred_field=pred_field,
        gt_field=gt_field,
        output_field=output_field,
        case_sensitive=False,
        delegate=True,
    )

# %% [markdown]
# This metric computes **Semantic Similarity** using neural embeddings, measuring whether two texts have the same *meaning* rather than the same *characters*.
#
#
# 1. **Sentence Encoding**: Uses a pre-trained neural network (from `sentence-transformer`) to convert each text into a high-dimensional vector (embedding) that captures its meaning.
#
# 2. **Cosine Similarity**: Computes the angle between the two embedding vectors:
#
#    $$
#    \text{similarity} = \max(0, \cos(\text{embedding}_{\text{gt}}, \text{embedding}_{\text{pred}}))
#    $$
#
# 3. **Score**:
#    - **1.0** = semantically identical
#    - **0.0** = completely unrelated
#    - **0.0-1.0** = partial semantic overlap
#
# **Example:**
#
# - **"The car is fast"** vs **"The automobile is quick"** → ~0.95 (same meaning, different words)
# - **"hello"** vs **"helo"** → ~0.85 (similar meaning despite typo)
# - **"cat"** vs **"dog"** → ~0.6 (related concepts)
#
# **Comparison to Normalized Levenshtein Similarity:**
#
# **Levenshtein** measures character-level edits using string matching. It's very fast but penalizes any character difference, even if the meaning is preserved. Best for detecting typos, OCR errors, or when exact wording matters.
#
# **Semantic** measures meaning using neural embeddings. It's slower (requires model inference) but rewards conceptual equivalence regardless of wording. For example, "car" vs "automobile" scores 0.0 with Levenshtein but ~0.9 with Semantic.

# %%
import fiftyone.operators as foo
import os

os.environ["FIFTYONE_ALLOW_LEGACY_ORCHESTRATORS"] = "true"

sem_op = foo.get_operator(
    "@harpreetsahota/text-evaluation-metrics/compute_semantic_similarity"
)

# (pred_field, gt_field, output_field)
# sem_q_ = semantic similarity, Qwen vs GPT root
# sem_m_ = semantic similarity, Molmo vs GPT root
COMPARISON_PAIRS = [
    ("qwen3vl_summary_brief",    "gpt_summary_root_brief",    "sem_q_sum_brief"),
    ("qwen3vl_summary_detailed", "gpt_summary_root_detailed", "sem_q_sum_detailed"),
    ("qwen3vl_action_brief",     "gpt_action_root_brief",     "sem_q_act_brief"),
    ("qwen3vl_action_detailed",  "gpt_action_root_detailed",  "sem_q_act_detailed"),
    ("qwen3vl_action_actor",     "gpt_action_root_actor",     "sem_q_actor"),
    ("molmo_summary_brief",      "gpt_summary_root_brief",    "sem_m_sum_brief"),
    ("molmo_summary_detailed",   "gpt_summary_root_detailed", "sem_m_sum_detailed"),
    ("molmo_action_brief",       "gpt_action_root_brief",     "sem_m_act_brief"),
    ("molmo_action_detailed",    "gpt_action_root_detailed",  "sem_m_act_detailed"),
    ("molmo_action_actor",       "gpt_action_root_actor",     "sem_m_actor"),
]

for pred_field, gt_field, output_field in COMPARISON_PAIRS:
    sem_op(
        dataset,
        pred_field=pred_field,
        gt_field=gt_field,
        model_name="all-mpnet-base-v2",
        output_field=output_field,
        delegate=True,
    )

# %% [markdown]
# **What to look at:** Browse the bottom of the sorted view (lowest confidence). Are these actually bad annotations, or just paraphrases that look different? This is the limitation of lexical metrics — they can't tell the difference. A future extension here is a semantic similarity operator using sentence embeddings, which would score paraphrases much more accurately.

# %% [markdown]
# ---
# ## Section 5
#
# Now that we have both lexical and semantic agreement scores for every sample, we can slice the dataset into meaningful subsets — not just "good" and "bad", but a more nuanced three-way split that reveals something important about the limits of lexical evaluation alone.
#
# We'll demonstrate this using `summary_detailed` as our primary signal: it's the richest description field, so agreement or disagreement here is the most informative. The same pattern applies directly to any of the other four field pairs (`summary_brief`, `action_brief`, `action_detailed`, `action_actor`) — try them on your own and see if the distributions differ.

# %%
from fiftyone import ViewField as F

HIGH_LEX = 0.6
HIGH_SEM = 0.6
LOW_LEX  = 0.3
LOW_SEM  = 0.5

lex_q = F("lex_q_sum_detailed")
sem_q = F("sem_q_sum_detailed")
lex_m = F("lex_m_sum_detailed")
sem_m = F("sem_m_sum_detailed")

TAGS = {
    "qwen_agrees":        (sem_q >= HIGH_SEM) & (lex_q >= HIGH_LEX),
    "molmo_agrees":       (sem_m >= HIGH_SEM) & (lex_m >= HIGH_LEX),
    "triple_agreement":   (sem_q >= HIGH_SEM) & (sem_m >= HIGH_SEM),
    "triple_disagreement":(sem_q < LOW_SEM)   & (sem_m < LOW_SEM),
    "qwen_only":          (sem_q >= HIGH_SEM) & (sem_m < LOW_SEM),
    "molmo_only":         (sem_m >= HIGH_SEM) & (sem_q < LOW_SEM),
    "paraphrase":         (lex_q < LOW_LEX)   & (sem_q >= HIGH_SEM) &
                          (lex_m < LOW_LEX)   & (sem_m >= HIGH_SEM),
}

for tag, expr in TAGS.items():
    view = dataset.match(expr)
    view.tag_samples(tag)
    print(f"{tag:<25} → {len(view)} samples tagged")

# %% [markdown]
# ---
#
# ## What We Built
#
# We started with 1,144 videos and a set of annotations we had to take on faith. Every label was written by a model. No human ever watched these clips.
#
# That's increasingly the norm. The question isn't whether to use AI-generated annotations but if you can blindly trust them, and for which samples.
#
# Here's what we built to answer that:
#
# - **Three independent views of the same data.** Qwen3-VL-Embedding, Molmo2, and transcript embeddings each carve the dataset differently: visual semantics, spatial grounding, and spoken language. Where they agree on which videos are similar, that structure is real. Where they diverge, you've learned something about the data that no single model would have told you.
#
# - **An independent second opinion on the annotations.** Qwen3-VL and Molmo2 watched the same videos cold, with no knowledge of what GPT-OSS-120B wrote. Where all three models converge, confidence is high. Where they diverge and especially where one model agrees with GPT and the other doesn't. By doing this, you've found the hard cases worth a human look.
#
# - **A per-sample confidence map.** Lexical similarity tells you whether the words match. Semantic similarity tells you whether the *meaning* matches. The gap between them (samples with low lexical but high semantic scores) is the **paraphrase class**: descriptions that look like disagreements but aren't. Without both metrics, you'd be reviewing the wrong samples.
#
# **Tags that survive.** Every insight is written back to the dataset as a sample tag — `triple_agreement`, `triple_disagreement`, `qwen_only`, `molmo_only`, `paraphrase`. Open the App, filter by tag, and the confidence map is right there.
#
# ---
#
# ### The Workflow, Generalized
#
# The dataset doesn't matter. This workflow does — and it transfers directly to any video dataset with AI-generated labels:
#
# 1. **Explore before trusting** — understand the annotation structure, know what the pipeline actually produced
#
# 2. **Embed from multiple angles** — visual content, spatial grounding, language; each lens surfaces different structure
#
# 3. **Get a second opinion** — run an independent model, compare outputs field by field
#
# 4. **Quantify agreement** — a per-sample score turns qualitative inspection into a sortable, filterable, taggable signal
#
# The uncomfortable truth about AI-generated datasets is that they look authoritative. The labels are structured, consistent, and comprehensive. But consistency isn't correctness. The only way to know which annotations to trust is to ask another model and measure how much they agree.
#
# That's what you just did.
